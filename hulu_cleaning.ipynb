# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pycountry_convert as pc
from datetime import datetime

# %%
# Load the dataset
# put your file path here
file_path = 'hulu_titles.csv'
df = pd.read_csv(file_path)

# %%
df.head(10)
# Out:
#   show_id     type                           title director  cast  \
# 0      s1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1      s2    Movie                    Silent Night      NaN   NaN
# 2      s3    Movie                    The Marksman      NaN   NaN
# 3      s4    Movie                            Gaia      NaN   NaN
# 4      s5    Movie                        Settlers      NaN   NaN
# 5      s6  TV Show   The Halloween Candy Magic Pet      NaN   NaN
# 6      s7    Movie              The Evil Next Door      NaN   NaN
# 7      s8  TV Show          The Next Thing You Eat      NaN   NaN
# 8      s9  TV Show                          Queens      NaN   NaN
# 9     s10  TV Show                The Bachelorette      NaN   NaN
#
#          country        date_added  release_year rating   duration  \
# 0            NaN  October 24, 2021          2021  TV-MA        NaN
# 1            NaN  October 23, 2021          2020    NaN     94 min
# 2            NaN  October 23, 2021          2021  PG-13    108 min
# 3            NaN  October 22, 2021          2021      R     97 min
# 4            NaN  October 22, 2021          2021    NaN    104 min
# 5            NaN  October 22, 2021          2021    NaN   1 Season
# 6            NaN  October 21, 2021          2020    NaN     88 min
# 7            NaN  October 21, 2021          2021    NaN   1 Season
# 8            NaN  October 20, 2021          2021  TV-14   1 Season
# 9  United States  October 20, 2021          2003  TV-14  3 Seasons
#
#                                            listed_in  \
# 0                                   Comedy, Stand Up
# 1                             Crime, Drama, Thriller
# 2                                   Action, Thriller
# 3                                             Horror
# 4                          Science Fiction, Thriller
# 5                                       Family, Kids
# 6                                   Horror, Thriller
# 7  Cooking & Food, Documentaries, Lifestyle & Cul...
# 8                                       Drama, Music
# 9                                   Reality, Romance
#
#                                          description
# 0  ​Comedian Ricky Velez bares it all with his ho...
# 1  Mark, a low end South London hitman recently r...
# 2  A hardened Arizona rancher tries to protect an...
# 3  A forest ranger and two survivalists with a cu...
# 4  Mankind's earliest settlers on the Martian fro...
# 5  Join Mila and Morphle on a mystery-filled Hall...
# 6  New to her role as a stepmom, a young woman mo...
# 7  With the unique insights and experience of Ugl...
# 8  Four women in their 40s reunite for a chance t...
# 9  ABC's romance reality show lets one lucky lady...

# %%
dict(df['release_year'].value_counts(), sorted=True)
# Out:
# {2019: np.int64(412),
#  2020: np.int64(377),
#  2018: np.int64(270),
#  2017: np.int64(229),
#  2021: np.int64(226),
#  2016: np.int64(165),
#  2015: np.int64(163),
#  2014: np.int64(129),
#  2013: np.int64(126),
#  2012: np.int64(119),
#  2011: np.int64(86),
#  2009: np.int64(78),
#  2010: np.int64(73),
#  2006: np.int64(57),
#  2007: np.int64(47),
#  2008: np.int64(46),
#  2005: np.int64(42),
#  2004: np.int64(37),
#  2003: np.int64(31),
#  2001: np.int64(28),
#  1999: np.int64(25),
#  2002: np.int64(25),
#  2000: np.int64(23),
#  1998: np.int64(23),
#  1997: np.int64(21),
#  1993: np.int64(16),
#  1995: np.int64(15),
#  1996: np.int64(14),
#  1994: np.int64(14),
#  1989: np.int64(10),
#  1990: np.int64(9),
#  1988: np.int64(8),
#  1985: np.int64(7),
#  1991: np.int64(7),
#  1992: np.int64(7),
#  1984: np.int64(7),
#  1972: np.int64(6),
#  1982: np.int64(6),
#  1986: np.int64(6),
#  1965: np.int64(5),
#  1987: np.int64(5),
#  1979: np.int64(5),
#  1963: np.int64(4),
#  1953: np.int64(4),
#  1981: np.int64(4),
#  1983: np.int64(4),
#  1957: np.int64(4),
#  1970: np.int64(3),
#  1950: np.int64(3),
#  1973: np.int64(3),
#  1975: np.int64(3),
#  1962: np.int64(3),
#  1974: np.int64(3),
#  1964: np.int64(2),
#  1971: np.int64(2),
#  1951: np.int64(2),
#  1959: np.int64(2),
#  1966: np.int64(2),
#  1969: np.int64(2),
#  1978: np.int64(2),
#  1955: np.int64(2),
#  1958: np.int64(2),
#  1980: np.int64(2),
#  1967: np.int64(2),
#  1977: np.int64(1),
#  1960: np.int64(1),
#  1923: np.int64(1),
#  1933: np.int64(1),
#  1968: np.int64(1),
#  1961: np.int64(1),
#  1954: np.int64(1),
#  1976: np.int64(1),
#  'sorted': True}

# %%
df_cleaned = df[(df['release_year'] >= 2010) & (df['release_year'] <= 2021)].copy()

# %%
df_cleaned
# Out:
#      show_id     type                            title director  cast  \
# 0         s1    Movie   Ricky Velez: Here's Everything      NaN   NaN
# 1         s2    Movie                     Silent Night      NaN   NaN
# 2         s3    Movie                     The Marksman      NaN   NaN
# 3         s4    Movie                             Gaia      NaN   NaN
# 4         s5    Movie                         Settlers      NaN   NaN
# ...      ...      ...                              ...      ...   ...
# 3047   s3048  TV Show     Black Butler: Book of Circus      NaN   NaN
# 3048   s3049  TV Show  Blade Dance of the Elementalers      NaN   NaN
# 3051   s3052  TV Show                 Doctora Juguetes      NaN   NaN
# 3064   s3065  TV Show                    Scream Queens      NaN   NaN
# 3070   s3071  TV Show                        The Fades      NaN   NaN
#
#              country        date_added  release_year rating   duration  \
# 0                NaN  October 24, 2021          2021  TV-MA        NaN
# 1                NaN  October 23, 2021          2020    NaN     94 min
# 2                NaN  October 23, 2021          2021  PG-13    108 min
# 3                NaN  October 22, 2021          2021      R     97 min
# 4                NaN  October 22, 2021          2021    NaN    104 min
# ...              ...               ...           ...    ...        ...
# 3047           Japan               NaN          2014  TV-14   1 Season
# 3048           Japan               NaN          2014  TV-14   1 Season
# 3051             NaN               NaN          2012   TV-Y   1 Season
# 3064   United States               NaN          2015  TV-14  2 Seasons
# 3070  United Kingdom               NaN          2011  TV-14   1 Season
#
#                                    listed_in  \
# 0                           Comedy, Stand Up
# 1                     Crime, Drama, Thriller
# 2                           Action, Thriller
# 3                                     Horror
# 4                  Science Fiction, Thriller
# ...                                      ...
# 3047                Action, Adventure, Anime
# 3048                Action, Adventure, Anime
# 3051                            Kids, Latino
# 3064                 Comedy, Horror, Mystery
# 3070  Horror, International, Science Fiction
#
#                                             description
# 0     ​Comedian Ricky Velez bares it all with his ho...
# 1     Mark, a low end South London hitman recently r...
# 2     A hardened Arizona rancher tries to protect an...
# 3     A forest ranger and two survivalists with a cu...
# 4     Mankind's earliest settlers on the Martian fro...
# ...                                                 ...
# 3047  When children begin to vanish after the arriva...
# 3048  The prestigious Areishia Spirit Academy has tr...
# 3051  Una mágica serie animada acerca de Doc McStuff...
# 3064  SCREAM QUEENS is a new genre-bending comedy-ho...
# 3070  Seventeen-year-old Paul is haunted by apocalyp...
#
# [2375 rows x 12 columns]

# %%
dict(df_cleaned['country'].value_counts())
# Out:
# {'United States': np.int64(679),
#  'Japan': np.int64(167),
#  'United Kingdom': np.int64(80),
#  'Canada': np.int64(29),
#  'United Kingdom, United States': np.int64(16),
#  'Canada, United States': np.int64(14),
#  'Australia': np.int64(14),
#  'United States, Canada': np.int64(10),
#  'United States, United Kingdom': np.int64(10),
#  'South Korea': np.int64(9),
#  'Germany': np.int64(4),
#  'Spain': np.int64(3),
#  'United Kingdom, United States, Canada': np.int64(3),
#  'United States, Australia': np.int64(3),
#  'Russia': np.int64(3),
#  'France': np.int64(3),
#  'Italy, United States': np.int64(3),
#  'United States, South Korea': np.int64(2),
#  'Sweden, Denmark, United States': np.int64(2),
#  'New Zealand': np.int64(2),
#  'Germany, Luxembourg': np.int64(2),
#  'Ireland': np.int64(2),
#  'Denmark': np.int64(2),
#  'Ireland, Belgium, United States': np.int64(2),
#  'Mexico': np.int64(2),
#  'Israel': np.int64(2),
#  'Norway': np.int64(2),
#  'Switzerland, United Kingdom, France, United States': np.int64(1),
#  'Colombia, United States': np.int64(1),
#  'Germany, France, United States': np.int64(1),
#  'Bulgaria, United States': np.int64(1),
#  'Australia, United States, United Kingdom, India, Singapore': np.int64(1),
#  'Austria, United Kingdom, Germany, France': np.int64(1),
#  'Sweden, France, Norway, Denmark': np.int64(1),
#  'Australia, United States, United Kingdom': np.int64(1),
#  'United Kingdom, Germany, United States': np.int64(1),
#  'Italy': np.int64(1),
#  'Canada, France': np.int64(1),
#  'Colombia, Argentina, Netherlands, Germany, Sweden, Uruguay, United States, Switzerland, Denmark, France': np.int64(1),
#  'United Kingdom, Belgium, United States': np.int64(1),
#  'Denmark, Sweden, France, Germany': np.int64(1),
#  'Finland, Germany, Canada, Sweden, France': np.int64(1),
#  'Venezuela': np.int64(1),
#  'United States, Netherlands, United Kingdom, Denmark': np.int64(1),
#  'Denmark, Germany, France, United Kingdom, United States, Qatar, Syria': np.int64(1),
#  'Australia, United States': np.int64(1),
#  'Austria, Australia, Germany, United States': np.int64(1),
#  'United States, Bulgaria': np.int64(1),
#  'Italy, France': np.int64(1),
#  'Italy, Belgium': np.int64(1),
#  'Greece, New Zealand': np.int64(1),
#  'Colombia': np.int64(1),
#  'United States, China': np.int64(1),
#  'Japan, Taiwan': np.int64(1),
#  'United Kingdom, Australia, New Zealand, United States': np.int64(1),
#  'United States, France': np.int64(1),
#  'Sweden, France': np.int64(1),
#  'France, Belgium, United States': np.int64(1),
#  'Norway, France, Denmark, Sweden': np.int64(1),
#  'United States, Canada, Mexico': np.int64(1),
#  'United States, United Kingdom, Australia, Canada': np.int64(1),
#  'United States, Mexico': np.int64(1),
#  'Sweden, Denmark, Finland': np.int64(1),
#  'Italy, Brazil, Germany, France, Sweden, United States': np.int64(1),
#  'Finland, United Kingdom, Canada': np.int64(1),
#  'United Kingdom, Ireland, United States, Germany, Japan, France': np.int64(1),
#  'Romania, United States': np.int64(1),
#  'France, Belgium': np.int64(1),
#  'Belgium, France, Netherlands': np.int64(1),
#  'Iceland, Poland, Denmark, Germany, France': np.int64(1),
#  'Germany, Luxembourg, Denmark, Belgium, China': np.int64(1),
#  'United Arab Emirates, Hong Kong': np.int64(1),
#  'Ireland, United Kingdom': np.int64(1),
#  'United Kingdom, India, Germany, China, United States': np.int64(1),
#  'France, Spain, Romania, Belgium, United States': np.int64(1),
#  'Sweden, Denmark': np.int64(1),
#  'Germany, Czech Republic': np.int64(1),
#  'United Kingdom, Sweden, Norway': np.int64(1),
#  'Chile, Colombia, Spain, United States': np.int64(1),
#  'United Kingdom, Israel, United States': np.int64(1),
#  'United Kingdom, Australia': np.int64(1),
#  'United States, Australia, Colombia, French Polynesia, Saudi Arabia': np.int64(1),
#  'United Kingdom, Philippines, Hungary, United States': np.int64(1),
#  'United States, United Kingdom, Italy': np.int64(1),
#  'Sweden, United States, Germany, United Kingdom': np.int64(1),
#  'Germany, Norway': np.int64(1),
#  'United States, Italy': np.int64(1),
#  'United Kingdom, United Arab Emirates': np.int64(1),
#  'Chile, Netherlands, Spain, Germany, United States': np.int64(1),
#  'United States, Canada, Ireland': np.int64(1),
#  'United Kingdom, Sweden, Germany': np.int64(1),
#  'Poland, United Kingdom, Ukraine': np.int64(1),
#  'United Kingdom, France, United States, China': np.int64(1),
#  'Germany, Belgium': np.int64(1),
#  'Australia, United Kingdom': np.int64(1),
#  'United Kingdom, France, United States': np.int64(1),
#  'Russia, United States': np.int64(1),
#  'United Kingdom, Spain, Ireland, United States': np.int64(1),
#  'Italy, France, Germany': np.int64(1),
#  'United States, South Africa': np.int64(1),
#  'United States, Canada, United Kingdom': np.int64(1),
#  'Mexico, United States': np.int64(1),
#  'United States, Denmark': np.int64(1),
#  'United States, Czech Republic, Spain': np.int64(1),
#  'United States, United Kingdom, Germany, Canada': np.int64(1),
#  'United Kingdom, Canada, United States': np.int64(1),
#  'Ireland, United Kingdom, Germany, Sweden': np.int64(1),
#  'United States, Bulgaria, Spain, Germany': np.int64(1),
#  'United States, Germany, Bulgaria, China': np.int64(1),
#  'France, Germany, Bulgaria, United States': np.int64(1),
#  'Ireland, France': np.int64(1),
#  'United Kingdom, Denmark, United States': np.int64(1),
#  'United States, Hong Kong': np.int64(1),
#  'United States, Costa Rica': np.int64(1),
#  'United States, Ireland': np.int64(1),
#  'United States, Germany, Norway, United Kingdom, Montenegro': np.int64(1),
#  'Canada, United Kingdom, United States': np.int64(1),
#  'Australia, United Arab Emirates': np.int64(1),
#  'United States, United Kingdom, Australia': np.int64(1),
#  'United States, Serbia, Canada': np.int64(1),
#  'Canada, United States, Mexico': np.int64(1),
#  'Afghanistan, United States': np.int64(1),
#  'Romania, France, Germany, Sweden': np.int64(1),
#  'Canada, United States, Spain, South Korea': np.int64(1),
#  'Denmark, France, Sweden, Germany, Belgium, Tunisia': np.int64(1),
#  'Switzerland, France, Belgium, United States': np.int64(1),
#  'Ireland, United Kingdom, Sweden, Belgium, United States': np.int64(1),
#  'Canada, United Kingdom': np.int64(1),
#  'United States, Mexico, Australia': np.int64(1),
#  'France, Canada': np.int64(1),
#  'Sweden, United States': np.int64(1),
#  'United States, Japan': np.int64(1),
#  'France, Germany': np.int64(1),
#  'China, United States': np.int64(1),
#  'Czech Republic, United Kingdom, United States, France': np.int64(1),
#  'United Kingdom, Ireland': np.int64(1)}

# %%
df_cleaned['country_cleaned'] = df_cleaned['country'].apply(lambda x: x.split(',') if pd.notna(x) else x)

# %%
df_cleaned.reset_index(inplace=True, drop=True)
nan = []
more = []
single = []
for i in range(len(df_cleaned)):
    try:
        if len(df_cleaned['country_cleaned'][i]) > 1:
            more.append(df_cleaned['country_cleaned'][i])
        else:
            single.append(df_cleaned['country_cleaned'][i])
    except:
        nan.append(df_cleaned['country_cleaned'][i])

# %%
df_cleaned.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director           2372
# cast               2375
# country            1196
# date_added            5
# release_year          0
# rating              490
# duration            428
# listed_in             0
# description           3
# country_cleaned    1196
# dtype: int64

# %%
def country_to_continent(country_name):
    country_alpha2 = pc.country_name_to_country_alpha2(country_name)
    country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
    country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
    return country_continent_name

continents = []
for i in range(len(df_cleaned)):
    try:
        if len(df_cleaned['country_cleaned'][i]) == 1:
            continents.append(country_to_continent(country_name=df_cleaned['country_cleaned'][i][0]))
        else:
            continents.append("Multi-Continent")
    except:
        continents.append(np.nan)

# %%
df_cleaned['continent'] = continents

# %%
df_cleaned.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description country_cleaned continent
# 0  ​Comedian Ricky Velez bares it all with his ho...             NaN       NaN
# 1  Mark, a low end South London hitman recently r...             NaN       NaN
# 2  A hardened Arizona rancher tries to protect an...             NaN       NaN
# 3  A forest ranger and two survivalists with a cu...             NaN       NaN
# 4  Mankind's earliest settlers on the Martian fro...             NaN       NaN

# %%
df_cleaned.dropna(subset=['date_added'], inplace=True)

# %%
df_cleaned.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director           2367
# cast               2370
# country            1195
# date_added            0
# release_year          0
# rating              490
# duration            428
# listed_in             0
# description           3
# country_cleaned    1195
# continent          1195
# dtype: int64

# %%
# remove space from date_added
df_cleaned['date_added'] = df_cleaned['date_added'].str.strip()

# convert 'date_added' to datetime type
df_cleaned['date_added'] = pd.to_datetime(df_cleaned['date_added'], format='%B %d, %Y')

# extract 'month', 'day', and 'year' from 'date_added'
df_cleaned['month'] = df_cleaned['date_added'].dt.month
df_cleaned['day'] = df_cleaned['date_added'].dt.day
df_cleaned['year'] = df_cleaned['date_added'].dt.year

# calculate the difference in months
# https://stackoverflow.com/questions/4039879/best-way-to-find-the-months-between-two-dates
def diff_month(d1, d2):
    return (d1.year - d2.year) * 12 + d1.month - d2.month

# create 'difference' in months
df_cleaned['difference'] = df_cleaned.apply(lambda row: diff_month(row['date_added'], datetime(row['release_year'], 1, 1)), axis=1)

# %%
df_cleaned.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#   date_added  release_year rating duration                  listed_in  \
# 0 2021-10-24          2021  TV-MA      NaN           Comedy, Stand Up
# 1 2021-10-23          2020    NaN   94 min     Crime, Drama, Thriller
# 2 2021-10-23          2021  PG-13  108 min           Action, Thriller
# 3 2021-10-22          2021      R   97 min                     Horror
# 4 2021-10-22          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description country_cleaned  \
# 0  ​Comedian Ricky Velez bares it all with his ho...             NaN
# 1  Mark, a low end South London hitman recently r...             NaN
# 2  A hardened Arizona rancher tries to protect an...             NaN
# 3  A forest ranger and two survivalists with a cu...             NaN
# 4  Mankind's earliest settlers on the Martian fro...             NaN
#
#   continent  month  day  year  difference
# 0       NaN     10   24  2021           9
# 1       NaN     10   23  2021          21
# 2       NaN     10   23  2021           9
# 3       NaN     10   22  2021           9
# 4       NaN     10   22  2021           9

# %%
df_cleaned.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director           2367
# cast               2370
# country            1195
# date_added            0
# release_year          0
# rating              490
# duration            428
# listed_in             0
# description           3
# country_cleaned    1195
# continent          1195
# month                 0
# day                   0
# year                  0
# difference            0
# dtype: int64

# %% [markdown]
# * Checking multi-continent (Maybe there are multiple countries but they might be from the same continent)

# %%
df_cleaned['continent'].unique()
# Out:
# array([nan, 'North America', 'Asia', 'Europe', 'Multi-Continent',
#        'Oceania', 'South America'], dtype=object)

# %%
# df_cleaned['continent'].value_counts()
continents_mix = {}
for i in list(df_cleaned[df_cleaned['continent']=='Multi-Continent'].index):
    tmp_cont = []
    for country in df_cleaned.loc[i]['country_cleaned']:
        if country.strip():
            try:
                tmp_cont.append(country_to_continent(country_name=country.strip()))
            except:
                print(i, country)
    continents_mix[i] = tmp_cont

# %%
for k, v in continents_mix.items():
    if list(set(v)).__len__() == 1:
        df_cleaned['continent'][k] = list(set(v))[0]
    else:
        df_cleaned['continent'][k] = "Multi-Continent"
# Out:
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# ...
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = list(set(v))[0]
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = "Multi-Continent"
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['continent'][k] = "Multi-Continent"

# %%
df_cleaned['continent'].value_counts()
# Out:
# continent
# North America      738
# Asia               178
# Europe             126
# Multi-Continent    115
# Oceania             16
# South America        2
# Name: count, dtype: int64

# %% [markdown]
# * Oceania is basically Australia, New Zealand and a few other pacific islands --> from internet (we can replace it to australia as well)

# %%
df_cleaned['type'].value_counts()
# Out:
# type
# TV Show    1193
# Movie      1177
# Name: count, dtype: int64

# %%
'''
ratings = {
    'Movie Ratings': {
        'G': 'General Audience - All ages.',
        'PG': 'Parental Guidance - Some material not suitable for children.',
        'PG-13': 'Parents Cautioned - Some material may not be suitable for under 13.',
        'R': 'Restricted - Under 17 requires an adult guardian.',
        'NC-17': 'Adults Only - No one 17 and under admitted.',
        'NR': 'Not Rated - Older movies before rating system.',
        'UR': 'Unrated - Often direct-to-video or re-releases with added content.'
    },
    'TV Ratings': {
        'TV-Y': 'All Children - For very young children (2-6 years old).',
        'TV-Y7': 'Older Children - Suitable for 7 and up.',
        'TV-Y7-FV': 'Older Children - May contain intense fantasy violence.',
        'TV-G': 'General Audience - Suitable for all ages.',
        'TV-PG': 'Parental Guidance - May contain moderate language or violence.',
        'TV-14': 'Parents Cautioned - May contain strong language or violence.',
        'TV-MA': 'Mature Audience - Unsuitable for children under 17.'
    }
}

'''

# %%
df_cleaned['duration'].value_counts(), df_cleaned['duration'].nunique()
# Out:
# (duration
#  1 Season      705
#  2 Seasons     220
#  3 Seasons      86
#  4 Seasons      67
#  5 Seasons      42
#               ...
#  142 min         1
#  63 min          1
#  65 min          1
#  70 min          1
#  22 Seasons      1
#  Name: count, Length: 111, dtype: int64,
#  111)

# %%
df_cleaned.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director           2367
# cast               2370
# country            1195
# date_added            0
# release_year          0
# rating              490
# duration            428
# listed_in             0
# description           3
# country_cleaned    1195
# continent          1195
# month                 0
# day                   0
# year                  0
# difference            0
# dtype: int64

# %%
len(df_cleaned)
# Out:
# 2370

# %%
df_cleaned.dropna(subset=['country_cleaned', 'continent', 'rating', 'duration'], inplace=True)

# %%
df_cleaned.reset_index(inplace=True, drop=True)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_id          894 non-null    object
#  1   type             894 non-null    object
#  2   title            894 non-null    object
#  3   director         2 non-null      object
#  4   cast             0 non-null      float64
#  5   country          894 non-null    object
#  6   date_added       894 non-null    datetime64[ns]
#  7   release_year     894 non-null    int64
#  8   rating           894 non-null    object
#  9   duration         894 non-null    object
#  10  listed_in        894 non-null    object
#  11  description      894 non-null    object
#  12  country_cleaned  894 non-null    object
#  13  continent        894 non-null    object
#  14  month            894 non-null    int32
#  15  day              894 non-null    int32
#  16  year             894 non-null    int32
#  17  difference       894 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int32(3), int64(2), object(11)
# memory usage: 115.4+ KB

# %%
season = 0
minu = 0
for i in range(len(df_cleaned)):
    if df_cleaned['duration'][i].lower().__contains__("season"):
        season+=1
    elif df_cleaned['duration'][i].lower().__contains__("min"):
        minu+=1

season, minu
# Out:
# (625, 269)

# %%
duration_min = []
duration_season = []
for i in range(len(df_cleaned)):
    if df_cleaned['duration'][i].lower().__contains__("season"):
        duration_season.append(df_cleaned['duration'][i].lower().strip("seasons").strip("season").strip())
    else:
        duration_season.append("NA")
    if df_cleaned['duration'][i].lower().__contains__("min"):
        duration_min.append(df_cleaned['duration'][i].lower().strip("min").strip())
    else:
        duration_min.append(np.nan)

# %%
len(duration_min), len(duration_season)
# Out:
# (894, 894)

# %%
df_cleaned['duration_min'] = duration_min
df_cleaned['duration_season'] = duration_season

# %%
df_cleaned['continent'].value_counts()
# Out:
# continent
# North America      573
# Asia               155
# Multi-Continent     86
# Europe              71
# Oceania              8
# South America        1
# Name: count, dtype: int64

# %%
df_cleaned.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'country_cleaned', 'continent', 'month', 'day', 'year', 'difference',
#        'duration_min', 'duration_season'],
#       dtype='object')

# %%
df_cleaned = df_cleaned[['type', 'date_added', 'month', 'day', 'year', 'release_year', 'rating', 'duration_min', 'duration_season', 
                         'difference', 'continent', 'country_cleaned', 'country', 'duration', 'listed_in', 'description', 'show_id', 'director', 
                         'cast', 'title']]

# %%
df_cleaned.columns
# Out:
# Index(['type', 'date_added', 'month', 'day', 'year', 'release_year', 'rating',
#        'duration_min', 'duration_season', 'difference', 'continent',
#        'country_cleaned', 'country', 'duration', 'listed_in', 'description',
#        'show_id', 'director', 'cast', 'title'],
#       dtype='object')

# %%
df_cleaned.head(2)
# Out:
#       type date_added  month  day  year  release_year rating duration_min  \
# 0  TV Show 2021-10-15     10   15  2021          2012  TV-14          NaN
# 1  TV Show 2021-10-15     10   15  2021          2011  TV-14          NaN
#
#   duration_season  difference      continent  country_cleaned        country  \
# 0               1         117  North America  [United States]  United States
# 1               6         129  North America  [United States]  United States
#
#     duration                     listed_in  \
# 0   1 Season        Documentaries, History
# 1  6 Seasons  Documentaries, Reality, Teen
#
#                                          description show_id director  cast  \
# 0  America's story can be told in many ways. Whil...     s18      NaN   NaN
# 1  Beyond Scared Straight profiles the new approa...     s20      NaN   NaN
#
#                        title
# 0  America's Book of Secrets
# 1     Beyond Scared Straight

# %%
def df_normalize_strings(df, col):
    df[col] = df[col].str.lower() # change everything to lower cases
    df[col] = df[col].fillna('missing') # make None -> missing
    df[col] = df[col].replace(np.nan, 'missing')
    df[col] = df[col].replace('none or unspecified', 'missing')
    df[col] = df[col].replace('none', 'missing')
    df[col] = df[col].replace('no', 'missing')
    df[col] = df[col].replace('#name?', 'missing')
    df[col] = df[col].replace('', 'missing') # empty -> missing
def normalize_all_columns(df):
    for col in df.columns:
        if df[col].dtype == 'object':  # Only apply to string columns
            df_normalize_strings(df, col)

# %%
normalize_all_columns(df_cleaned)

# %%
df_cleaned.dtypes
# Out:
# type                       object
# date_added         datetime64[ns]
# month                       int32
# day                         int32
# year                        int32
# release_year                int64
# rating                     object
# duration_min               object
# duration_season            object
# difference                  int64
# continent                  object
# country_cleaned            object
# country                    object
# duration                   object
# listed_in                  object
# description                object
# show_id                    object
# director                   object
# cast                      float64
# title                      object
# dtype: object

# %%
df_cleaned.to_csv("Hulu_cleaned_1.csv", index=False)

# %%
'''
WE CAN CHANGE THE ORDER OF THE QUESTIONS LATER ON TO FORM A MEANINGFUL FLOW

#1 (gopi)
Question: trend of how long does netflix take to add on the show of past vs current
Columns req: "difference", "type"
Comments: We can include the type as well (like how lon TV shows take to be added to Netflix in comparison to Movies)
Business perspective can be: If the time to be added to Netflix from the release date is lesser, it's a good point to attract the customers

#2 (ricky)
Question: are there any notictable patterns in type/content released over the past years. Which type has gotten more popular and released more
Columns req: "date_added"/"year", "type", "duration", "listed_in"
comments: we can plot something like, year/date will be on one axis and the other axis will have type | duration | listed_in (maybe a 1x3 subplots)
          we can also different plots for tv shows and movies since their duration values are different.
Business perspective: if there are more tv shows than movies, it indicates that netflix is trying increase the watch hours of the users since,
                         tv shows have more watch hours compared to movies (need to figure out, can't think of any good idea here).

#3 (victor)
Question: what age group are they targeting distrution of rating
Columns req: "rating", count of "type", "year" (maybe to show the trend in target audience)
comments: 
Business perspective: more content in the rating of "anyone can watch sort of type" means that the range and count of target audience
                     is more thus increasing the subscriptions (??? not quite sure here as well)

#4 (gopi)
Question: Global visualization
Columns req: "continent", ("country"),
business perspective: netflix catering to global audience

#5
Question: key directors and cast in the netflix ecosystem.
comments: Network graph of top directors/csat and their genres. (optional-not sure if this would work out, keeping it for now)

#6 (victor)
Question: use quarterly data to get counts of type released and see what types of shows are popular during which season
comments: Since most people have holidays in Dec/Jan, is the content more likely around tht season?
'''

# %%
df_cleaned.isnull().sum()
# Out:
# type                 0
# date_added           0
# month                0
# day                  0
# year                 0
# release_year         0
# rating               0
# duration_min         0
# duration_season      0
# difference           0
# continent            0
# country_cleaned      0
# country              0
# duration             0
# listed_in            0
# description          0
# show_id              0
# director             0
# cast               894
# title                0
# dtype: int64
