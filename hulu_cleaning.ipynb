# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pycountry_convert as pc
from datetime import datetime

# %%
# Load the dataset
# put your file path here
file_path = 'hulu_titles.csv'
df = pd.read_csv(file_path)

# %%
df.head(10)
# Out:
#   show_id     type                           title director  cast  \
# 0      s1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1      s2    Movie                    Silent Night      NaN   NaN
# 2      s3    Movie                    The Marksman      NaN   NaN
# 3      s4    Movie                            Gaia      NaN   NaN
# 4      s5    Movie                        Settlers      NaN   NaN
# 5      s6  TV Show   The Halloween Candy Magic Pet      NaN   NaN
# 6      s7    Movie              The Evil Next Door      NaN   NaN
# 7      s8  TV Show          The Next Thing You Eat      NaN   NaN
# 8      s9  TV Show                          Queens      NaN   NaN
# 9     s10  TV Show                The Bachelorette      NaN   NaN
#
#          country        date_added  release_year rating   duration  \
# 0            NaN  October 24, 2021          2021  TV-MA        NaN
# 1            NaN  October 23, 2021          2020    NaN     94 min
# ...

# %%
dict(df['release_year'].value_counts(), sorted=True)
# Out:
# {2019: np.int64(412),
#  2020: np.int64(377),
#  2018: np.int64(270),
#  2017: np.int64(229),
#  2021: np.int64(226),
#  2016: np.int64(165),
#  2015: np.int64(163),
#  2014: np.int64(129),
#  2013: np.int64(126),
#  2012: np.int64(119),
#  2011: np.int64(86),
#  2009: np.int64(78),
#  2010: np.int64(73),
#  2006: np.int64(57),
#  2007: np.int64(47),
#  2008: np.int64(46),
#  2005: np.int64(42),
#  2004: np.int64(37),
#  2003: np.int64(31),
#  2001: np.int64(28),
#  1999: np.int64(25),
#  2002: np.int64(25),
#  2000: np.int64(23),
#  1998: np.int64(23),
#  1997: np.int64(21),
#  1993: np.int64(16),
#  1995: np.int64(15),
#  1996: np.int64(14),
#  1994: np.int64(14),
#  1989: np.int64(10),
#  1990: np.int64(9),
#  1988: np.int64(8),
#  1985: np.int64(7),
#  1991: np.int64(7),
#  1992: np.int64(7),
#  1984: np.int64(7),
#  1972: np.int64(6),
#  1982: np.int64(6),
#  1986: np.int64(6),
#  1965: np.int64(5),
#  1987: np.int64(5),
#  1979: np.int64(5),
#  1963: np.int64(4),
# ...

# %%
df_cleaned = df[(df['release_year'] >= 2010) & (df['release_year'] <= 2021)].copy()

# %%
df_cleaned
# Out:
#      show_id     type                            title director  cast  \
# 0         s1    Movie   Ricky Velez: Here's Everything      NaN   NaN
# 1         s2    Movie                     Silent Night      NaN   NaN
# 2         s3    Movie                     The Marksman      NaN   NaN
# 3         s4    Movie                             Gaia      NaN   NaN
# 4         s5    Movie                         Settlers      NaN   NaN
# ...      ...      ...                              ...      ...   ...
# 3047   s3048  TV Show     Black Butler: Book of Circus      NaN   NaN
# 3048   s3049  TV Show  Blade Dance of the Elementalers      NaN   NaN
# 3051   s3052  TV Show                 Doctora Juguetes      NaN   NaN
# 3064   s3065  TV Show                    Scream Queens      NaN   NaN
# 3070   s3071  TV Show                        The Fades      NaN   NaN
#
#              country        date_added  release_year rating   duration  \
# ...

# %%
dict(df_cleaned['country'].value_counts())
# Out:
# {'United States': np.int64(679),
#  'Japan': np.int64(167),
#  'United Kingdom': np.int64(80),
#  'Canada': np.int64(29),
#  'United Kingdom, United States': np.int64(16),
#  'Canada, United States': np.int64(14),
#  'Australia': np.int64(14),
#  'United States, Canada': np.int64(10),
#  'United States, United Kingdom': np.int64(10),
#  'South Korea': np.int64(9),
#  'Germany': np.int64(4),
#  'Spain': np.int64(3),
#  'United Kingdom, United States, Canada': np.int64(3),
#  'United States, Australia': np.int64(3),
#  'Russia': np.int64(3),
#  'France': np.int64(3),
#  'Italy, United States': np.int64(3),
#  'United States, South Korea': np.int64(2),
#  'Sweden, Denmark, United States': np.int64(2),
#  'New Zealand': np.int64(2),
#  'Germany, Luxembourg': np.int64(2),
#  'Ireland': np.int64(2),
#  'Denmark': np.int64(2),
#  'Ireland, Belgium, United States': np.int64(2),
#  'Mexico': np.int64(2),
#  'Israel': np.int64(2),
#  'Norway': np.int64(2),
# ...

# %%
df_cleaned['country_cleaned'] = df_cleaned['country'].apply(lambda x: x.split(',') if pd.notna(x) else x)

# %%
df_cleaned.reset_index(inplace=True, drop=True)
nan = []
more = []
single = []
for i in range(len(df_cleaned)):
    try:
        if len(df_cleaned['country_cleaned'][i]) > 1:
            more.append(df_cleaned['country_cleaned'][i])
        else:
            single.append(df_cleaned['country_cleaned'][i])
    except:
        nan.append(df_cleaned['country_cleaned'][i])

# %%
df_cleaned.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director           2372
# cast               2375
# country               2
# date_added            5
# release_year          0
# rating              490
# duration            428
# listed_in             0
# description           3
# country_cleaned       2
# dtype: int64

# %%
def country_to_continent(country_name):
    country_alpha2 = pc.country_name_to_country_alpha2(country_name)
    country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
    country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
    return country_continent_name

continents = []
for i in range(len(df_cleaned)):
    try:
        if len(df_cleaned['country_cleaned'][i]) == 1:
            continents.append(country_to_continent(country_name=df_cleaned['country_cleaned'][i][0]))
        else:
            continents.append("Multi-Continent")
    except:
        continents.append(np.nan)

# %%
df_cleaned['continent'] = continents

# %%
df_cleaned['continent'].value_counts()
# Out:
# continent
# North America      1608
# Asia                247
# Europe              185
# Multi-Continent     173
# Oceania              36
# South America        11
# Africa                4
# Name: count, dtype: int64

# %%
df_cleaned.head()
# Out:
#   show_id   type                           title director  cast       country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN           USA
# 1      s2  Movie                    Silent Night      NaN   NaN            UK
# 2      s3  Movie                    The Marksman      NaN   NaN           USA
# 3      s4  Movie                            Gaia      NaN   NaN  South Africa
# 4      s5  Movie                        Settlers      NaN   NaN            UK
#
#   date_added  release_year rating duration                  listed_in  \
# 0 2021-10-24          2021  TV-MA      NaN           Comedy, Stand Up
# 1 2021-10-23          2020    NaN   94 min     Crime, Drama, Thriller
# 2 2021-10-23          2021  PG-13  108 min           Action, Thriller
# 3 2021-10-22          2021      R   97 min                     Horror
# 4 2021-10-22          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description country_cleaned  \
# ...

# %%
df_cleaned.dropna(subset=['date_added'], inplace=True)

# %%
df_cleaned.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director           2367
# cast               2370
# country               1
# date_added            0
# release_year          0
# rating              490
# duration            428
# listed_in             0
# description           3
# country_cleaned       1
# continent           106
# month                 0
# day                   0
# year                  0
# difference            0
# dtype: int64

# %%
# remove space from date_added
df_cleaned['date_added'] = df_cleaned['date_added'].str.strip()

# convert 'date_added' to datetime type
df_cleaned['date_added'] = pd.to_datetime(df_cleaned['date_added'], format='%B %d, %Y')

# extract 'month', 'day', and 'year' from 'date_added'
df_cleaned['month'] = df_cleaned['date_added'].dt.month
df_cleaned['day'] = df_cleaned['date_added'].dt.day
df_cleaned['year'] = df_cleaned['date_added'].dt.year

# calculate the difference in months
# https://stackoverflow.com/questions/4039879/best-way-to-find-the-months-between-two-dates
def diff_month(d1, d2):
    return (d1.year - d2.year) * 12 + d1.month - d2.month

# create 'difference' in months
df_cleaned['difference'] = df_cleaned.apply(lambda row: diff_month(row['date_added'], datetime(row['release_year'], 1, 1)), axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[201], line 2
#       1 # remove space from date_added
# ----> 2 df_cleaned['date_added'] = df_cleaned['date_added'].str.strip()
#       4 # convert 'date_added' to datetime type
#       5 df_cleaned['date_added'] = pd.to_datetime(df_cleaned['date_added'], format='%B %d, %Y')
#
# File /opt/anaconda3/envs/msds/lib/python3.12/site-packages/pandas/core/generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# ...

# %%
df_cleaned.head()
# Out:
#   show_id   type                           title director  cast       country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN           USA
# 1      s2  Movie                    Silent Night      NaN   NaN            UK
# 2      s3  Movie                    The Marksman      NaN   NaN           USA
# 3      s4  Movie                            Gaia      NaN   NaN  South Africa
# 4      s5  Movie                        Settlers      NaN   NaN            UK
#
#   date_added  release_year rating duration                  listed_in  \
# 0 2021-10-24          2021  TV-MA      NaN           Comedy, Stand Up
# 1 2021-10-23          2020    NaN   94 min     Crime, Drama, Thriller
# 2 2021-10-23          2021  PG-13  108 min           Action, Thriller
# 3 2021-10-22          2021      R   97 min                     Horror
# 4 2021-10-22          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description country_cleaned  \
# ...

# %%
df_cleaned.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director           2367
# cast               2370
# country               1
# date_added            0
# release_year          0
# rating              490
# duration            428
# listed_in             0
# description           3
# country_cleaned       1
# continent           106
# month                 0
# day                   0
# year                  0
# difference            0
# dtype: int64

# %%
df_cleaned.to_csv("Hulu_for_difference.csv", index=False)

# %%
# list(df_cleaned[df_cleaned['country'].isnull()==True]['title'].values)[1000:1200]

# %% [markdown]
# # filling country nans

# %%
a = {
    "Ricky Velez: Here's Everything": "USA",
    'Silent Night': "UK",
    'The Marksman': "USA",
    'Gaia': "South Africa",
    'Settlers': "UK",
    'The Halloween Candy Magic Pet': "USA",
    'The Evil Next Door': "Sweden",
    'The Next Thing You Eat': "USA",
    'Queens': "USA",
    'The Real Queens of Hip-Hop: The Women Who Changed the Game': "USA",
    'Dream Horse': "UK",
    'Out of the Shadows: The Man Behind the Steele Dossier': "USA",
    'Wakefield': "Australia",
    'Home Sweet Home': "USA",
    'Showtime Championship Boxing: Lopez vs. Salido (R)': "USA",
    'Showtime Championship Boxing: Wilder vs. Molina': "USA",
    'Beyond Oak Island': "USA",
    'Cheer Camp Killer': "USA",
    'Marrying Millions': "USA",
    'Seven Year Switch': "USA",
    'Sleepwalker': "USA",
    'Unsolved': "USA",
    'Acapulco Shore': "Mexico",
    'Catfish México': "Mexico",
    'Censor': "UK",
    'Dani Who?': "USA",
    'La Culpa es de Cortés': "Spain",
    'Out of Death': "USA",
    'Why Not Us': "USA",
    'BELLATOR MMA: Kongo vs. Johnson 2': "USA",
    'CHIPS': "USA",
    'Dopesick': "USA",
    'In the Crease': "USA",
    'Champaign, Ill': "USA",
    'The Loneliest Whale: The Search for 52': "USA",
    'Gunda': "Norway",
    'Buried': "Spain",
    'G.I. Joe: Retaliation': "USA",
    'Rogue Hostage': "USA",
    'Roots Less Traveled': "USA",
    'Jacinta': "USA",
    'ABC News Live Prime with Linsey Davis': "USA",
    "Baker's Dozen": "USA",
    'FIFA World Cup 2022 Qualifying': "Various",
    'BELLATOR MMA 257: Nemkov vs. Davis 2 (R)': "USA",
    'BELLATOR MMA: Davis vs. Nemkov': "USA",
    "Maggie's Plan": "USA",
    'The Bradshaw Bunch': "USA",
    'Pacific Airshow': "USA",
    'The Most Magical Story On Earth: 50 Years of Walt Disney World': "USA",
    'Asylum': "USA",
    'Bite Size Halloween': "USA",
    "Blippi's Spooky Spell Halloween": "USA",
    'Cedar Rapids': "USA",
    'Date Night Extended Version': "USA",
    'Diary of a Wimpy Kid: Rodrick Rules': "USA",
    'Edge of the World': "Malaysia",
    'Happy Feet Two': "Australia",
    'Peeples': "USA",
    'Resident Evil: Retribution': "USA",
    'The Hunger Games': "USA",
    'The Hunger Games: Catching Fire': "USA",
    'The Hunger Games: Mockingjay, Part 1': "USA",
    'The Hunger Games: Mockingjay, Part 2': "USA",
    'The Vow': "USA",
    'Total Recall': "USA",
    'Unforgettable': "USA",
    'Within': "USA",
    'Wolves at the Door': "USA",
    'Entre Hombres': "Spain",
    'L.A. Rams Cheerleaders: Making the Squad': "USA",
    'True Crime: The Murder of Monica Leech': "USA",
    'Minor Premise': "USA",
    'Year of Extremes': "USA",
    'Felix and the Hidden Treasure': "Spain",
    'Wild Crime': "USA",
    'Nuclear Family': "USA",
    'BMF': "USA",
    'SEC Storied': "USA",
    'This World Alone': "USA",
    'Trolls: TrollsTopía': "USA",
    'Alter Ego': "USA",
    'El Árbol Familiar de los Croods': "USA",
    'Funhouse': "USA",
    'Home Economics': "USA",
    'The Croods: Family Tree': "USA",
    'The Wonder Years': "USA",
    'Will & Grace': "USA",
    'Grown Ups': "USA",
    'UFC Embedded': "USA",
    'America Strong': "USA",
    'Dark Side of Football': "USA",
    'Madagascar: Algo Salvaje': "USA",
    'Soul of a Nation Presents: Corazón de América -- Celebrating Hispanic Culture': "USA",
    'On Chesil Beach': "UK",
    'Riders of Justice': "Denmark",
    'Stalker': "Russia",
    'All About Nina': "USA",
    "Chuck's World": "USA",
    'Gilberto Santa Rosa, 40…y Contando': "USA"
}

# %%
b = {
    'Killer Cases': 'USA',
    'Level Playing Field': 'USA',
    'Los Croods 2: Una Nueva Era': 'USA',
    'Santana - Corazón: Live From Mexico, Live It to Believe It': 'Mexico',
    "Thalía 'Viva Tour' (En Vivo)": 'Mexico',
    'The King Stays King': 'USA',
    'Yandel: Legacy, De Lider a Leyenda Tour': 'Puerto Rico',
    'The Big Leap': 'USA',
    'Colette': 'UK',
    'John Bronco Rides Again': 'USA',
    'Y: The Last Man': 'USA',
    'Fruits Basket (2019)': 'Japan',
    'High Ground': 'Australia',
    'Detainee 001': 'USA',
    'Project Bakeover': 'USA',
    'Salvage Kings': 'Canada',
    'Worst to First': 'USA',
    'More Than An Athlete': 'USA',
    'Our Time: UCF Football': 'USA',
    'Women of 9/11: A Special Edition of 20/20 With Robin Roberts': 'USA',
    'La La Land': 'USA',
    '9/11 20 Years Later: Women of Resilience': 'USA',
    '9/11 Twenty Years Later: The Longest Shadow': 'USA',
    'Logan': 'USA',
    'Eyewitness to 9/11: Behind the Lens': 'USA',
    'CMA Summer Jam': 'USA',
    "The D'Amelio Show": 'USA',
    'Undine': 'Germany',
    'About Endlessness': 'Sweden',
    'Death in Texas': 'USA',
    'Made By Her: Monumental Women': 'USA',
    'SMU Football: The Hilltop': 'USA',
    'The Unthinkable': 'Sweden',
    'Eli’s Places': 'USA',
    "Free Willy: Escape From Pirate's Cove": 'USA',
    'I Spit on Your Grave': 'USA',
    'I Spit On Your Grave 2': 'USA',
    'I Spit on Your Grave 3': 'USA',
    'Miss You Already': 'UK',
    'Mommy': 'Canada',
    'Much Ado About Nothing': 'UK',
    "New Year's Eve": 'USA',
    'Priest': 'South Korea',
    'PRO14 Rugby': 'UK',
    'Shaun the Sheep Movie': 'UK',
    'Solace': 'USA',
    'Sucker Punch': 'USA',
    'That One Word: Feyenoord': 'Netherlands',
    'The Apparition': 'France',
    'The Possession': 'USA',
    'The Wedding Plan': 'Israel',
    'Final Hours, America’s Longest War': 'USA',
    'Only Murders in the Building': 'USA',
    '9/11: One Day in America': 'USA',
    'Are you the one? El match perfecto': 'Mexico',
    'Catfish Colombia': 'Colombia',
    'Drunk History Argentina': 'Argentina',
    'Spell': 'USA',
    'Super Shore': 'Spain',
    'Trigger Point': 'UK',
    'Earth Odyssey with Dylan Dreyer': 'USA',
    'Horizon Line': 'Sweden',
    'Four Good Days': 'USA',
    'Chaos Walking': 'USA',
    'In the Earth': 'UK',
    'Disobedience': 'UK',
    'Feral State': 'USA',
    'Love and Monsters': 'USA',
    'Comedy Central Presenta': 'USA',
    'La Culpa es de Colón': 'Spain',
    'La Culpa es de Colón: Edición Mujeres': 'Spain',
    'La Culpa es de Cortés: Edición Mujeres': 'Spain',
    'La Culpa es de Llorente': 'Spain',
    'The Ultimate Surfer': 'USA',
    'NYC Epicenters 9/11→2021½': 'USA',
    'The Unusual Suspects': 'USA',
    'Celebrity Wife Swap': 'USA',
    'Gossip': 'USA',
    'We Broke Up': 'USA',
    'Blast Beat': 'USA',
    'Bettor Days': 'USA',
    'Unsane': 'USA',
    'Heels': 'USA',
    'The Hate U Give': 'USA',
    'The Emoji Story': 'USA',
    'The Real Housewives of Salt Lake City': 'USA',
    'Heartbreak Hotel: Flight 800, 25 Years Later': 'USA',
    'Held': 'USA',
    'Homeroom': 'USA',
    'Superstar': 'USA',
    'The Force': 'Australia',
    'The Virtuoso': 'USA',
    'The Waiting Room': 'USA',
    'Fantasy Island': 'USA',
    'Secrets of the Morgue': 'USA',
    'The Fantasy Show': 'USA',
    'Reservation Dogs': 'USA',
    'UFO': 'USA',
    'English Championship Soccer': 'UK',
    'Texas: Spirit and Soul': 'USA'
}

# %%
c = {
    'Obama: In Pursuit of a More Perfect Union': 'USA',
    'The Devil You Know': 'USA',
    'Fear the Walking Dead en Español': 'USA',
    'Small Town News: KPVM Pahrump': 'USA',
    '30 Minutes or Less': 'USA',
    'Alpha and Omega': 'USA',
    'Attack the Block': 'UK',
    'Black Swan': 'USA',
    'Every Breath You Take': 'USA',
    'Freelancers': 'USA',
    'From Prada to Nada': 'USA',
    "Gulliver's Travels": 'USA',
    'Impossible Builds': 'UK',
    'Jack and Jill': 'USA',
    'Mirror Mirror': 'USA',
    'Mud': 'USA',
    'The Pier': 'Spain',
    'The Vatican Tapes': 'USA',
    'Transcendence': 'USA',
    'Chasing Trane: The John Coltrane Documentary': 'USA',
    'The Resort': 'USA',
    'Best Summer Ever': 'USA',
    'The Artist': 'France',
    'The Good Traitor': 'Denmark',
    'Blue Origin: Civilians in Space': 'USA',
    '100 Foot Wave': 'USA',
    'The Last Dance': 'USA',
    'Power Book III: Raising Kanan': 'USA',
    'The Deceived': 'Ireland',
    'WWE Friday Night SmackDown': 'USA',
    'Los intrépidos': 'Mexico',
    'McCartney 3, 2, 1': 'USA',
    '20,000 Days on Earth': 'UK',
    'A Field in England': 'UK',
    'American Horror Stories': 'USA',
    'Amira & Sam': 'USA',
    'Borgman': 'Netherlands',
    'Bullhead': 'Belgium',
    'Cheap Thrills': 'USA',
    'Enforcement': 'Denmark',
    'Exit Plan': 'Denmark',
    'I Declare War': 'Canada',
    'Mood Indigo': 'France',
    'Pieta': 'South Korea',
    'Raiders!: The Story of the Greatest Fan Film Ever Made': 'USA',
    'Sonny Boy': 'Netherlands',
    'The Act of Killing': 'Indonesia',
    'The Complex: Lockdown': 'Japan',
    'The Congress': 'Israel',
    'The Connection': 'France',
    'The Final Member': 'Iceland',
    'The FP': 'USA',
    'The Keeping Room': 'USA',
    'Backyard Builds': 'Canada',
    'Cleopatra en el Espacio': 'Mexico',
    'Cleopatra in Space': 'USA',
    'Save My Reno': 'Canada',
    'Love Island (UK)': 'UK',
    '47 Meters Down': 'UK',
    'Entre Nos Presents: Frankie Quiñones: Superhomies': 'USA',
    'UFC 264': 'USA',
    'Barb and Star Go to Vista Del Mar': 'USA',
    'Detail: Daniel Cormier': 'USA',
    'In a World...': 'USA',
    'Pete Lee: Tall, Dark, and Pleasant': 'USA',
    "Blippi's Summer Games": 'USA',
    'Red Penguins': 'USA',
    'Home to Win': 'Canada',
    'Love & Service: The Carter Story': 'USA',
    'Dreamcatcher': 'USA',
    'Flower of Evil': 'South Korea',
    'How a Realist Hero Rebuilt the Kingdom': 'Japan',
    "I'll Go to You When the Weather is Nice": 'South Korea',
    'More Than Friends': 'South Korea',
    'Bill & Ted Face the Music': 'USA',
    'Born a Champion': 'USA',
    'Dark Web: Cicada 3301': 'USA',
    'Fear of Rain': 'USA',
    'Silk Road': 'USA',
    'Summer of Soul': 'USA',
    'The Case Study of Vanitas': 'Japan',
    'The Right One': 'USA',
    '127 Hours': 'USA',
    '68 Kill': 'USA',
    'Almost Human': 'USA',
    'Alpha and Omega 4: The Legend of the Saw Toothed Cave': 'USA',
    'An Acceptable Loss': 'USA',
    'Band Aid': 'USA',
    'Beats, Rhymes & Life: The Travels of A Tribe Called Quest': 'USA',
    'Best of Cheddar': 'USA',
    'Bitter Harvest': 'Ukraine',
    'Bohemian Rhapsody': 'UK',
    'Carnage Park': 'USA',
    'Chuck': 'USA',
    "Dealin' With Idiots": 'USA',
    'Dear White People': 'USA',
    'Donnybrook': 'USA',
    'Elaine Stritch: Shoot Me': 'USA',
    'Free to Run': 'France',
    'Gimme The Loot': 'USA'
}

# %%
d = {
    'Graduation': 'Romania',
    'Hellions': 'Canada',
    'Higurashi: When They Cry - NEW': 'Japan',
    'I Remember You': 'Iceland',
    'Last Days Here': 'USA',
    "Let's Be Evil": 'UK',
    'Ode to Joy': 'USA',
    'Passage to Mars': 'USA',
    'Personal Shopper': 'France',
    'Pikwik Pack en Español': 'Canada',
    'Rabid Dogs': 'France',
    "RuPaul's Drag Race": 'USA',
    'Shelley': 'Denmark',
    'Sightseers': 'UK',
    'Stonewall': 'USA',
    'Stray': 'Turkey',
    'Sweet Virginia': 'USA',
    'Take Shelter': 'USA',
    "The Angel's Share": 'UK',
    'The Face of Love': 'USA',
    'The Feels': 'USA',
    'The Girl With the Dragon Tattoo': 'Sweden',
    'The Mighty Ones': 'USA',
    'The Unknown Girl': 'Belgium',
    'They Came Together': 'USA',
    'Underworld Awakening': 'USA',
    'Big Food Bucket List': 'Canada',
    'Escape to Alcatraz': 'USA',
    'Hansel & Gretel: Witch Hunters': 'USA',
    'Jack Reacher': 'USA',
    'On The Red Carpet': 'USA',
    'Texas True Crime': 'USA',
    'TMZ Investigates: UFOs: The Pentagon Proof': 'USA',
    'Wall of Chefs': 'Canada',
    'Harvie and the Magic Museum': 'Belgium',
    'Tulsa Burning: The 1921 Race Massacre': 'USA',
    'Safer at Home': 'USA',
    'The Choe Show': 'USA',
    'False Positive': 'USA',
    'Junior Chef Showdown': 'USA',
    'When Nature Calls With Helen Mirren': 'UK',
    'Elvis Presley: The Searcher': 'USA',
    'Battle Over Britney: The Conservatorship Hearing': 'USA',
    'Capital One: College Bowl': 'USA',
    'Monster Trucks': 'USA',
    'Blood on the Wall': 'USA',
    'Family Home Overhaul': 'Canada',
    'Farmhouse Facelift': 'Canada',
    'Hot Market': 'USA',
    'Switched at Birth': 'USA',
    'The Guilt Trip': 'USA',
    'Juneteenth: Together We Triumph -- A Soul of a Nation Special Event': 'USA',
    'Rise Again: Tulsa and the Red Summer': 'USA',
    'The Doorman': 'USA',
    'The Hustler': 'USA',
    'Phobias': 'USA',
    'Accused: Guilty or Innocent?': 'USA',
    'Alone: The Beast': 'USA',
    'America: Our Defining Hours': 'USA',
    'Born to Play': 'USA',
    'Dance Moms': 'USA',
    'Her Deadly Sugar Daddy': 'USA',
    'Her Name Is Chef': 'USA',
    'Michael Smerconish: Things I Wish I Knew Before I Started Talking': 'USA',
    'Mountain Men': 'USA',
    'Nasrin': 'USA',
    'The Celebrity Dating Game': 'USA',
    'The Obituary of Tunde Johnson': 'USA',
    'Rūrangi': 'New Zealand',
    'The Housewife and the Hustler': 'USA',
    'Blindspotting': 'USA',
    "Willy's Wonderland": 'USA',
    'UFC 263': 'USA',
    'Come True': 'Canada',
    'Pride on ABC News Live': 'USA',
    'The Real Rebel: The Erin Brockovich Story': 'USA',
    'House Rules': 'Australia',
    "Sarah Beeny's Renovate Don't Relocate": 'UK',
    'The Great House Revival': 'UK',
    'Trust': 'USA',
    'Two of Us': 'France',
    'The Croods: A New Age': 'USA',
    'Killer Women with Piers Morgan': 'UK',
    'The American Royal Baby': 'USA',
    'The Insider: Reggie Yates': 'UK',
    "Tom Kerridge's American Feast": 'UK',
    'Little Birds': 'UK',
    'The Kings': 'France',
    'Juan Luis Guerra 4.40: Entre Mar y Palmeras': 'Dominican Republic',
    'Quest for the Stanley Cup': 'Canada',
    'A Glitch in the Matrix': 'USA',
    'Night of the Kings': 'Ivory Coast',
    'E60': 'USA',
    'Changing the Game': 'USA',
    'Drag SOS': 'UK',
    'HouseBroken': 'USA',
    'Inside Missguided': 'UK',
    'Into': 'USA',
    'Savage State': 'France',
    'Sex Party 101': 'USA'
}

# %%
e = {
    'Silence': 'USA',
    'The Adventures of Tintin: The Secret of the Unicorn': 'USA/Belgium',
    'The Donut King': 'USA',
    'The World to Come': 'USA',
    'Lavell Crawford: The Comedy Vaccine': 'USA',
    'My 600-lb Life': 'USA',
    'The Vigil': 'USA',
    'Unusual Suspects: Deadly Intent': 'USA',
    'Crime Scene Kitchen': 'USA',
    'The $100,000 Pyramid': 'USA',
    'After Floyd: The Year that Shook the World': 'USA',
    'Mike Tyson: The Knockout': 'USA',
    'Baewatch: Parental Guidance': 'USA',
    'Escape from the City': 'UK',
    'The Ultimate Fighter': 'USA',
    'Vanguard': 'China',
    'Flatbush Misdemeanors': 'USA',
    "Marvel's M.O.D.O.K.": 'USA',
    'Red Dawn': 'USA',
    "Tulsa's Buried Truth": 'USA',
    'My Little Pony: Pony Life en Español': 'USA',
    'Supernova': 'UK/Australia',
    'Supernova en Español': 'UK/Australia',
    'Death and Nightingales': 'UK/Ireland',
    'A Perfect Ending': 'USA',
    'ABC News Live Honors Asian Pacific American Heritage Month: Bridging Generations': 'USA',
    'Cowboys': 'USA',
    'Galacticos': 'Spain',
    'Good Kisser': 'USA',
    'LaLiga Center': 'Spain',
    'LaLiga Top Moments': 'Spain',
    'Mosquita y Mari': 'USA',
    'Pride': 'UK',
    'Reaching for the Moon': 'Brazil',
    'The Mountain Between Us': 'USA',
    'Tru Love': 'Canada',
    'UFC 262': 'USA',
    'United States of LaLiga': 'Spain',
    'MLK/FBI': 'USA',
    'Saint Maud': 'UK',
    'Some Kind of Heaven': 'USA',
    'The Crime of the Century': 'USA',
    'Robot & Frank': 'USA',
    'Little Fish': 'USA',
    'Eyewitness to a Pandemic': 'USA',
    "Total Recall(ed): The Story of America's Largest, Wildest Recall Election": 'USA',
    'Shadow in the Cloud': 'New Zealand',
    'Skyfall': 'UK',
    'Deadly Women': 'Australia',
    'Love Sarah': 'UK',
    'Pikwik Pack': 'Canada',
    "The Legend of Baron To'a": 'New Zealand',
    'Flight': 'USA',
    "An Elephant's Journey": 'South Africa',
    'Are You the One?': 'USA',
    'Blind Date': 'UK',
    'Dating: No Filter': 'USA',
    "Dr. Bird's Advice for Sad Poets": 'USA',
    'Grudge Match': 'USA',
    'I Love You Phillip Morris': 'USA',
    'Married to Medicine': 'USA',
    'Shahs of Sunset': 'USA',
    'Texicanas': 'USA',
    'The Age of Adaline': 'USA',
    'The Judge': 'USA',
    'The Night': 'USA',
    'Presidential Address to Congress and the Nation and the Republican Response': 'USA',
    'Arrival': 'USA',
    'Sesame Street: 50 Years of Sunny Days': 'USA',
    'Exposure': 'UK',
    'Una Familia Moderna': 'USA',
    'Wild Mountain Thyme': 'Ireland',
    'UFC 261: Early Prelims and Prelims': 'USA',
    'Billie': 'USA',
    'Better Days': 'Hong Kong',
    'Breaking Fast': 'USA',
    'Greta Thunberg: A Year to Change the World': 'UK',
    'Cruel Summer': 'USA',
    "It's Not Too Late: Earth Day Special": 'USA',
    'More in Common': 'USA',
    'Sasquatch': 'USA',
    'Set the Record Straight: The Jam Master Jay Case': 'USA',
    'The Lynching of Henry ‘Peg’ Gilbert': 'USA',
    'Confronting a Serial Killer': 'USA',
    'Modern Persuasion': 'USA',
    'Sister of the Groom': 'USA',
    'Celebrity Best Home Cook': 'UK',
    'Fly Like a Girl': 'USA',
    'Songbird': 'USA',
    'Deep in Vogue': 'UK',
    'The State of Texas vs. Melissa': 'USA',
    'Valley Grown': 'USA',
    'The First 100 Days: President Biden Takes Office': 'USA',
    'The First 100 Days: Rep. Nancy Mace and Rep. Marilyn Strickland': 'USA',
    'Cleveland Clinic: A Century of Care': 'USA',
    'Paranormal Activity 4': 'USA',
    'Spontaneous': 'USA',
    'Knuckledust': 'UK',
    'Hope & Desperation: Emergency at the Border': 'USA'
}

# %%
f = {
    'Quo Vadis, Aida?': 'Bosnia and Herzegovina',
    'Stars Fell on Alabama': 'USA',
    'The Bridge': 'Sweden/Denmark',
    'The Standard': 'USA',
    'The World Ends with You: The Animation': 'Japan',
    'A Christmas Hero': 'USA',
    'Crock of Gold: A Few Rounds With Shane MacGowan': 'UK',
    'Ip Man: Kung Fu Master': 'China',
    'Girl': 'Belgium',
    'Malika the Lion Queen': 'South Africa',
    'Megalobox': 'Japan',
    'Blair Witch': 'USA',
    'Hysterical': 'USA',
    'Law & Order: Organized Crime': 'USA',
    'WeWork: or The Making and Breaking of a $47 Billion Unicorn': 'USA',
    'A Hologram for the King': 'USA',
    'Amy Schumer Learns to Cook': 'USA',
    "Blippi's Great Green Adventure": 'USA',
    'Chappaquiddick': 'USA',
    'Chopped Sweets': 'USA',
    'Extreme Makeover: Home Edition': 'USA',
    'My Little Pony: Pony Life': 'USA',
    'Second Act': 'USA',
    'Step Up Revolution': 'USA',
    'The Black Full Monty': 'UK',
    'Tournament of Champions': 'USA',
    'Undercover Billionaire': 'USA',
    'Vegas Chef Prizefight': 'USA',
    'Zappa': 'USA',
    'ABCNL Prime With Linsey Davis': 'USA',
    '5 Years Apart': 'USA',
    'Blood Moon': 'USA',
    'The Hurricane Heist': 'USA',
    'Collective': 'Romania',
    'Shortcut': 'Italy',
    'The Orange Years: The Nickelodeon Story': 'USA',
    '100% Wolf': 'Australia',
    'Teen Wolf': 'USA',
    'The Gloaming': 'Australia',
    'Hunter Hunter': 'USA',
    'Odd Man Rush': 'USA',
    'ABC News Exclusive: President Joe Biden with George Stephanopoulos': 'USA',
    'TrueSouth': 'USA',
    'Holmes Family Effect': 'USA',
    "America's Most Wanted": 'USA',
    'Staged': 'UK',
    '1 Night in San Diego': 'USA',
    'Another Round': 'Denmark',
    'Constructing Albert': 'Spain',
    'Corporate Animals': 'USA',
    'Crown Vic': 'USA',
    'GameStopped': 'USA',
    'Grand Isle': 'USA',
    'H. H. Holmes: Original Evil': 'USA',
    'Intersect': 'USA',
    'Missing 411: The Hunted': 'USA',
    'Naughty Books': 'USA',
    'People of Earth': 'USA',
    'Roadies': 'USA',
    'Robert the Bruce': 'UK',
    'Sister Aimee': 'USA',
    'The Man Who Killed Don Quixote': 'Spain/UK/France',
    'The Stand: How One Gesture Shook the World': 'USA',
    'Blood and Money': 'USA',
    'Buddy Games': 'USA',
    '32 Seconds: A Deadly Night in Rome': 'Italy',
    'Farewell Amor': 'USA',
    'I Met a Girl': 'Australia',
    'Kid 90': 'USA',
    'Black Death': 'UK',
    'Game of Talents': 'USA',
    'Absolutely Ascot': 'UK',
    'Dress to Impress': 'UK',
    'Bart & Hahn': 'USA',
    'GREENY': 'USA',
    'Shipwrecked 2019': 'UK',
    "Stephen A's World": 'USA',
    'Proxima': 'France',
    'Storks': 'USA',
    'Triggered': 'USA',
    'Ammonite': 'UK',
    'Beirut': 'USA',
    'Boss Level': 'USA',
    'Dear Santa': 'USA',
    'Iron Mask': 'China/Russia',
    'Step Up: High Water': 'USA',
    'Stop the Hate: The Rise in Violence Against Asian Americans': 'USA',
    'Soul of a Nation': 'USA',
    'Attack of the 50 Foot Cheerleader': 'USA',
    'CoComelon': 'USA',
    'Little Baby Bum': 'UK',
    'Priceless': 'USA',
    'Florence Foster Jenkins': 'UK/USA',
    'Jersey Shore: Family Vacation': 'USA',
    'SportsNation': 'USA',
    'The United States vs. Billie Holiday': 'USA',
    'Stardust': 'UK',
    'Beartown': 'Sweden',
    'Dredd': 'UK',
    'Spring Baking Championship': 'USA'
}

# %%
g = {
    'Supervillain: The Making of Tekashi 6ix9ine': 'USA',
    'A Conversation With Black Women': 'USA',
    'ABC News Live Presents: Mission to Mars, Live!': 'USA',
    'Sonic the Hedgehog': 'USA',
    'The March on Washington: Keepers of the Dream': 'USA',
    'Kenan': 'USA',
    'Logan Lucky': 'USA',
    'Bad Habits, Holy Orders': 'UK',
    'North Korea: Inside the Mind of a Dictator': 'UK',
    'The Warrior Queen of Jhansi': 'India',
    'Trump: The Reckoning': 'USA',
    'Lost Girls & Love Hotels': 'USA',
    'Mommy is a Murderer': 'USA',
    'Southern Gothic': 'USA',
    'Tempted by Danger': 'USA',
    'The Shape of Water': 'USA',
    'Witches of Salem': 'USA',
    'Crshd': 'USA',
    'Men in Kilts: A Roadtrip with Sam and Graham': 'UK',
    'A Conversation Between Black Men': 'USA',
    'Havana Street Party Presents: Beatriz Luengo': 'Spain',
    'Hip Hop Uncovered': 'USA',
    '2067': 'Australia',
    'Tentacles': 'Italy',
    "You're Next": 'USA',
    'Black Love': 'USA',
    'Then Came You': 'USA',
    'OnlyFans: Selling Sexy': 'USA',
    'Black Stories Presents: Your Attention Please': 'USA',
    'Our America: Living While Black': 'USA',
    'Hello, My Name Is Doris': 'USA',
    'Possessor': 'Canada',
    'The Game': 'USA',
    'The Undefeated': 'USA',
    'Dogs Playing Poker': 'USA',
    'WWE en Español': 'USA',
    'Tattoo Fixers Extreme UK': 'UK',
    'Gretel & Hansel': 'USA',
    'Name That Tune': 'USA',
    "Gordon Ramsay's American Road Trip": 'UK',
    'Mighty Oak': 'USA',
    'The Wall': 'USA',
    'Hell or High Water': 'USA',
    'Star Trek Beyond': 'USA',
    'Super Dark Times': 'USA',
    'Inside the College Football Playoff': 'USA',
    'The Year: 2020': 'USA',
    'The Little Hours': 'USA',
    'Adoption Day': 'USA',
    'Best Animal Friends': 'USA',
    'Comeback Kids': 'USA',
    'First Taste Of Freedom': 'USA',
    'Rescued': 'USA',
    'Reunited': 'USA',
    'Happiest Season: Holiday Yule Log Scenic': 'USA',
    'Up Early Tonight': 'USA',
    'The Shot: Race for the Vaccine -- A Special Edition of 20/20': 'USA',
    'Rent-a-Pal': 'USA',
    'Robin Roberts Thrivership Awards': 'USA',
    'Rogue': 'USA',
    "Blippi's Snowflake Scavenger Hunt": 'USA',
    "Peyton's Places": 'USA',
    'UFC 252': 'USA',
    'The Great American Baking Show: Holiday Edition': 'USA',
    'Stand Up for Heroes': 'USA',
    'A3!': 'Japan',
    '69: The Saga of Danny Hernandez': 'USA',
    'Search and Destroy': 'USA',
    'Soul On Ice: Past, Present and Future': 'USA',
    'A Sap Story': 'USA',
    'Gingerbread Home Remodel': 'USA',
    'I Am Greta (Swedish Narration)': 'Sweden',
    'Library Cheer': 'USA',
    'Puppies Crash Christmas': 'USA',
    'Stuck Santa': 'USA',
    'The Gathering': 'USA',
    'Two Tickets to Christmastown': 'USA',
    'Entre Nos: About Last Night': 'USA',
    'The Man Who Invented Christmas': 'UK',
    'Country Strong 2020: Countdown to the CMA Awards -- An ABC News Special': 'USA',
    "Eater's Guide to the World": 'USA',
    'Vic the Viking and the Magic Sword': 'Germany',
    'The Day I Became a God': 'Japan',
    'Moonbase 8': 'USA',
    'Akudama Drive': 'Japan',
    'Bare Knuckle': 'UK',
    'The Cult of the Family': 'Australia',
    'Kuma Kuma Kuma Bear': 'Japan',
    'Our Last Crusade or the Rise of a New World': 'Japan',
    'Your Voice, Your Vote: Election 2020 - A Special Edition of 20/20': 'USA',
    'Secret Life of a Gang Girl: The Untold Story': 'USA',
    'All Summers End': 'USA',
    "Ayesha's Home Kitchen": 'USA',
    'Baby Steps': 'USA',
    'Best Baker in America': 'USA',
    'Flip or Flop Fort Worth': 'USA',
    "Giada's Holiday Handbook": 'USA',
    'Holiday Gingerbread Showdown': 'USA',
    "Mapplethorpe (Director's Cut)": 'USA',
    'Wetlands': 'Germany'
}

# %%
h = {
    "America's Future: The Power of the Latino Vote": 'USA',
    'Baking It Easy': 'USA',
    'Basic Versus Baller: Travel at Any Cost': 'USA',
    'Behind The Dish': 'USA',
    'Lightened Up': 'USA',
    'Make This Tonight': 'USA',
    'Sourced': 'USA',
    'The Grill Iron': 'USA',
    'The Women Who Run': 'USA',
    'Burger Scholar Sessions': 'USA',
    'Bad Hair': 'USA',
    'Behind Bars: Rookie Year': 'USA',
    'Beyond the Headlines: Escaping the NXIVM Cult with Gretchen Carlson': 'USA',
    'Born Behind Bars': 'USA',
    'Cheerleader Generation': 'USA',
    'Crazy Love': 'USA',
    'Dating App Horrors: The Untold Story': 'USA',
    'I Was a Child Bride: The Untold Story': 'USA',
    'Lost Gold of World War II': 'USA',
    'Meghan and Harry: Baby Fever': 'UK',
    'My Sordid Affair': 'USA',
    'Sex for Sale: The Untold Story': 'USA',
    'AMS: The Fight for Flight': 'USA',
    'Cyrano, My Love': 'France',
    'Madagascar: A Little Wild - A Fang-Tastic Halloween': 'USA',
    'Celeste & Jesse Forever': 'USA',
    'Hannibal': 'USA',
    'Totally Under Control': 'USA',
    'Supermarket Sweep': 'UK',
    'Friend Request': 'Germany',
    'Seduced: Inside the NXIVM Cult': 'USA',
    'Bad Hombres': 'USA',
    'Earth to Echo': 'USA',
    'Emperor': 'USA',
    'Helstrom': 'USA',
    'QT8: The First Eight': 'USA',
    'Life Without Basketball': 'USA',
    'The Con': 'USA',
    'The Purge en Español': 'USA',
    'Treadstone': 'USA',
    'Treadstone en Español': 'USA',
    'Hotel Transylvania': 'USA',
    'Inside Mayweather vs. Pacquiao': 'USA',
    'SCB: Davis vs. Walsh': 'USA',
    'Infamous': 'USA',
    "Entre Nos Presents: Shayla Rivera: It's Not Rocket Science": 'USA',
    'Terminator: Dark Fate': 'USA',
    'Books of Blood': 'USA',
    'Dragon Ball Super': 'Japan',
    "Let's Be Real": 'USA',
    'UFC Fight Island: Declassified': 'USA',
    '90 Day Fiancé: Before the 90 Days': 'USA',
    'Across the Line': 'USA',
    'Boonie Bears: The Big Shrink': 'China',
    'Halloween Baking Championship': 'USA',
    'Halloween Wars': 'USA',
    'Higurashi When They Cry': 'Japan',
    'Homicide City: Charlotte': 'USA',
    'Judy & Punch': 'Australia',
    'Kindred Spirits (2019)': 'USA',
    'Moonshiners: Master Distiller': 'USA',
    'My Feet Are Killing Me': 'USA',
    'Next Level': 'USA',
    'Stripped: Los Angeles': 'USA',
    'Supermarket Stakeout': 'USA',
    'Swimming for Gold': 'Australia',
    'The Sandman': 'USA',
    'Twisted Love': 'USA',
    'Soccer Made In Germany': 'Germany',
    'Weakest Link': 'UK',
    'Inherit the Viper': 'USA',
    'Trauma Center': 'USA',
    'UFC Ultimate Knockouts': 'USA',
    'A Wilderness of Error': 'USA',
    'Judy': 'UK',
    'S.W.A.T. en Español': 'USA',
    'I Can See Your Voice': 'USA',
    'The Apartment (TV)': 'USA',
    'Cosmos: Possible Worlds': 'USA',
    'Boonie Bears: Spring into Action': 'China',
    'Filthy Rich': 'USA',
    'The Addams Family': 'USA',
    'ESPN FC': 'USA',
    'Stars and Strife': 'USA',
    'The Haunted': 'USA',
    'Babyteeth': 'Australia',
    'Gemini Man': 'USA',
    "Sherman's Showcase": 'USA',
    'StarDog and TurboCat': 'UK',
    'The Fight': 'USA',
    'My Soul to Take': 'USA',
    'A.C.O.R.N.S: Operation Crack Down': 'USA',
    'Ozzy': 'USA',
    'The 3 Knockdown Rule': 'USA',
    'The Etruscan Smile': 'UK',
    'Pororo the Little Penguin': 'South Korea',
    "Bin Laden's Hard Drive": 'USA',
    'Pop Goes the Vet': 'USA',
    'Woke': 'USA',
    'This is How U Hulu': 'USA'
}

# %%
i = {
    'Vacation In Place': 'USA',
    'Playmobil: The Movie': 'France/Germany',
    'Strike': 'UK',
    "I'll Be Gone In The Dark": 'USA',
    'Bucket List Bistro': 'USA',
    'Nazi Megastructures': 'UK',
    'Mediterranean Life': 'USA',
    'Before Midnight': 'USA',
    'Come As You Are': 'USA',
    'Our Time: Oklahoma State Football': 'USA',
    'Mission Overview: NASA’s Perseverance Mars Rover': 'USA',
    'NASA Science Live: Perseverance Mars Rover & the Search for Ancient Life': 'USA',
    "Jerry Garcia: It's Not My Weekend": 'USA',
    'Shark vs. Surfer': 'USA',
    'United Sharks of America: Shark Bite Capitals': 'USA',
    'Mega Hammerhead: Ultimate Predator': 'USA',
    "America's Caddie": 'USA',
    'What the Shark?': 'USA',
    "Cocoa Butter's The Era": 'USA',
    'Borderforce USA': 'UK',
    'Raging Bull Shark': 'USA',
    "World's Biggest Great White? Expedition Hawaii": 'USA',
    'Auditions': 'USA',
    'Most Wanted Sharks': 'USA',
    'Sharks vs. Dolphins: Blood Battle': 'USA',
    'When Sharks Attack': 'USA',
    "World's Biggest Tiger Shark?": 'USA',
    'Ana': 'USA',
    'The Pickup Game': 'USA',
    'The Wolf Hour': 'USA',
    'The Traitor': 'Italy',
    'The Weekend': 'USA',
    'The New York Times Presents': 'USA',
    'Dicktown': 'USA',
    'EvanTubeHD Smiles & Smarts by pocket.watch': 'USA',
    'HobbyKidsTV Smiles & Smarts by pocket.watch': 'USA',
    'Jason Vlogs Smiles & Smarts by pocket.watch': 'USA',
    "Jillian's Mystery Craft Box by pocket.watch": 'USA',
    'JillianTubeHD Smiles & Smarts by pocket.watch': 'USA',
    'Karina Garcia Smiles & Smarts by pocket.watch': 'USA',
    'KidCity Smiles & Smarts by pocket.watch': 'USA',
    'MarMar Land Smiles & Smarts by pocket.watch': 'USA',
    'Onyx Family Smiles & Smarts by pocket.watch': 'USA',
    "Ryan's World Specials presented by pocket.watch": 'USA',
    'Scratch Garden Smiles & Smarts by pocket.watch': 'USA',
    '90 Day Fiancé: The Other Way': 'USA',
    "Burgers, Brew & 'Que": 'USA',
    'Chris Farley: Anything for a Laugh': 'USA',
    'Family by the Ton': 'USA',
    'Ghost Hunters': 'USA',
    'Married at First Sight: Jamie and Doug Plus One': 'USA',
    'Psychic Kids': 'USA',
    'Say Yes to the Nest': 'USA',
    'Digimon Adventure:': 'Japan',
    'Wild Nights With Emily': 'USA',
    'The Rape of Recy Taylor': 'USA',
    'UFC 250': 'USA',
    'Juneteenth: A Celebration of Overcoming': 'USA',
    'Eye In The Sky': 'UK',
    'Soccer': 'UK',
    "Tyler Perry's The Haves and the Have Nots": 'USA',
    'Why We Fight': 'USA',
    'Frankie': 'USA',
    'A Beautiful Day in the Neighborhood': 'USA',
    'Hard': 'USA',
    'Childrens Hospital': 'USA',
    'Inside 30 for 30': 'USA',
    'Maximilian': 'Germany',
    'The 10 Year Plan': 'USA',
    'Westworld': 'USA',
    'Women and Sometimes Men': 'USA',
    'Rig 45': 'Denmark',
    'Miles From Tomorrowland': 'USA',
    'Mission Force One': 'USA',
    'UFC 249': 'USA',
    'AKA Jane Roe': 'USA',
    'Killer in Plain Sight': 'USA',
    '2nd Date Sex': 'USA',
    'Da Sweet Blood of Jesus': 'USA',
    'Morphle': 'UK',
    'Scandal': 'USA',
    'Beat Bobby Flay': 'USA',
    'Saving Flora': 'USA',
    'The Boy Downstairs': 'USA',
    'Delivered': 'USA',
    'Pain and Glory': 'Spain',
    'Vikings': 'Ireland/USA',
    'After Class': 'USA',
    'Unlocking Victory': 'USA',
    'Bloom (AUS)': 'Australia',
    'Ghost Team (Unrated)': 'USA',
    'In the Radiant City': 'USA',
    'Missing 411': 'USA',
    'Toxic Beauty': 'USA',
    'Sophie La Girafe': 'France',
    'Hubble 30th Anniversary': 'USA',
    'Detail: 1998 Chicago Bulls': 'USA',
    'Little People, Big World': 'USA',
    'Songland': 'USA',
    '13 Assassins': 'Japan'
}

# %%
j = {
    'Pooka Lives!': 'USA',
    '90 Day Fiancé: Happily Ever After?': 'USA',
    'Hatfields & McCoys': 'USA',
    'Hidden Potential': 'USA',
    'The Food That Built America': 'USA',
    'The Witch': 'USA',
    'Brown Girl Begins': 'Canada',
    'Margaret Atwood: A Word After a Word After a Word is Power': 'Canada',
    'Little Fires Everywhere': 'USA',
    'Gravity': 'Mexico',
    'Yu-Gi-Oh! ARC-V': 'Japan',
    'Big Time Adolescence': 'USA',
    'Monchhichi': 'Japan',
    'Crawlers': 'USA',
    'Hillary': 'USA',
    'I Draw, You Cook': 'USA',
    'Flesh And Bone (TV)': 'USA',
    'Extreme Rescues': 'USA',
    "OK K.O.! Let's Be Heroes": 'USA',
    'Último Tren A Rusia': 'Spain',
    'Guardians of the Amazon': 'Brazil',
    'Alive': 'South Korea',
    'Smile Down the Runway': 'Japan',
    'Wrong Man': 'USA',
    'Toilet-bound Hanako-kun': 'Japan',
    'My Valentine': 'USA',
    'Mamon': 'Spain',
    'Basketball: A Love Story': 'USA',
    'UFC 246': 'USA',
    'WWE Miz and Mrs': 'USA',
    'Tom Brady’s Big Super Bowl Announcement': 'USA',
    'Howards End': 'UK',
    'Magi': 'Japan',
    'Magi 2': 'Japan',
    'My little Pony: A Very Minty Christmas en Español': 'USA',
    'My Little Pony: Friendship is Magic en Español': 'USA',
    'Nisekoi 2': 'Japan',
    'Serie Pokémon XY': 'Japan',
    'Serie Pokémon XY – Expediciones en Kalos': 'Japan',
    'Serie Pokémon XYZ': 'Japan',
    'Sword Art Online II': 'Japan',
    'Brian Banks': 'USA',
    'Luce': 'USA',
    'Emanuel': 'USA',
    'The Detour': 'USA',
    'Justified en Español': 'USA',
    'Greener Grass': 'USA',
    'Coherence': 'USA',
    'NASA Explorers': 'USA',
    'Rare Exports: A Christmas Tale': 'Finland',
    'Lodge 49': 'USA',
    'Honeyland': 'North Macedonia',
    'Raise Hell: The Life and Times of Molly Ivins': 'USA',
    '¿Dónde Está Elisa?': 'Chile',
    'C.B. Strike': 'UK',
    "Hunting JonBenét's Killer: The Untold Story": 'USA',
    'Rellik': 'UK',
    'The Zen Diaries of Garry Shandling': 'USA',
    'Cabin Fever: Patient Zero': 'USA',
    'D.L. Hughley: Reset': 'USA',
    'Day of the Falcon': 'UAE',
    'Digging Up the Marrow': 'USA',
    'Odd Thomas': 'USA',
    "Playin' For Love": 'USA',
    'So This Is Christmas': 'USA',
    'Andy & the Donald': 'USA',
    'Lil Rel Howery: Live in Crenshaw': 'USA',
    'Preacher': 'USA',
    'CFB150': 'USA',
    'Littlekenny': 'Canada',
    'New Order: Decades': 'UK',
    'Pokémon the Movie: Diancie and the Cocoon of Destruction': 'Japan',
    'Pokémon the Movie: Hoopa and the Clash of Ages': 'Japan',
    'Pokémon The Movie: Volcanion and the Mechanical Marvel': 'Japan',
    'Pokémon the Series: XY': 'Japan',
    'Pokémon the Series: XY Kalos Quest': 'Japan',
    'Pokémon the Series: XYZ': 'Japan',
    'A Christmas Carol (2019)': 'UK',
    'Cold Case Hammarskjöld': 'Denmark',
    "Marvel's Runaways": 'USA',
    'Fast Color': 'USA',
    'Catherine the Great': 'UK',
    'The Harder Way': 'USA',
    'A Nasty Piece of Work': 'USA',
    'Eddie Griffin: E-Niggma': 'USA',
    'Love & Mercy': 'USA',
    'Ice Age: A Mammoth Christmas': 'USA',
    'Vita & Virginia': 'UK',
    'UFC Sound Waves': 'USA',
    'Fantastica: A Boonie Bears Adventure': 'China',
    'Case file n°221 : Kabukicho': 'France',
    'Special 7: Special Crime Investigation Unit': 'Japan',
    'Kono Oto Tomare!: Sounds of Life': 'Japan',
    'After School Dice Club': 'Japan',
    'Celeste Barber: Challenge Accepted': 'Australia',
    'Investigations by Vice': 'USA',
    'Pilgrim': 'USA',
    'Snake City': 'USA',
    'The Boardroom': 'USA',
    'Ultimate Survival WWII': 'USA'
}

# %%
k = {
    'Raw. Vegan. Not Gross.': 'USA',
    'HobbyKids Adventures by pocket.watch': 'USA',
    'Daytime Noir': 'USA',
    'The World Between Us': 'Taiwan',
    'Little Woods': 'USA',
    'Sword Art Online -Alicization-': 'Japan',
    'Scotch: A Golden Dream': 'UK',
    'Alex Morgan: The Equalizer': 'USA',
    'Uncanny Annie': 'USA',
    'The Dunes': 'USA',
    '30 for 30': 'USA',
    'Hillbilly': 'USA',
    'The Amityville Murders': 'USA',
    'Love & Hip Hop Hollywood': 'USA',
    'Drifters': 'Japan',
    'Joe Bennett Collection': 'USA',
    'Culture Shock: A Conversation With Director Gigi Saul Guerrero': 'USA',
    'Dios, Inc.': 'Mexico',
    'Murder in the Bayou': 'USA',
    'Nitro Circus: The Movie': 'USA',
    'Backstory': 'USA',
    'Pure': 'UK',
    'The Many Lives of Nick Buoniconti': 'USA',
    'Buried Secrets of WWII': 'USA',
    'Playing It Cool': 'USA',
    "Dana White's Contender Series": 'USA',
    'The Affair': 'USA',
    'Farruko: En Letra de Otro': 'Puerto Rico',
    'Shark Movers: Deadly Cargo': 'USA',
    'Forecast Shark Attack': 'USA',
    'The Whale That Ate Jaws: Eyewitness Report': 'USA',
    'Great Shark Chow Down': 'USA',
    'Cannibal Sharks': 'USA',
    'AWOL': 'USA',
    'Apollo: Back to the Moon': 'USA',
    'Kochoki': 'South Korea',
    'The Armstrong Tapes': 'USA',
    'The Ones Within': 'Japan',
    'ASTRA LOST IN SPACE': 'Japan',
    'Big Little Lies': 'USA',
    'Non-Fiction': 'France',
    'School Spirit': 'USA',
    'Hackerville': 'Romania',
    'After Darkness': 'USA',
    'Blue Bloods': 'USA',
    'ISS Expedition': 'USA',
    "Clair de Lune 4K Version - Moon Images from NASA's Lunar Reconnaissance Orbiter": 'USA',
    'Earth Views': 'USA',
    'NASA Discusses Recent Testing of the James Webb Space Telescope': 'USA',
    "NASA's Giant Leaps: Past and Future - Celebrating Apollo 50th as we Go Forward to the Moon": 'USA',
    'NASA’s Look at 50 Years of Apollo': 'USA',
    'Parker Solar Probe Launch Coverage': 'USA',
    'Space Station Fisheye Fly-Through': 'USA',
    'SpaceX Crew Dragon’s First Launch on Demo-1 Mission': 'USA',
    'SpaceX TESS Live Launch Coverage': 'USA',
    'Stunning Aurora Borealis from Space': 'USA',
    'Tour of the Moon 4k Redux': 'USA',
    'Somm': 'USA',
    'SneakerCenter': 'USA',
    'Chernobyl': 'UK',
    'Nightwatch Nation': 'USA',
    'El Jardin De Bronce': 'Argentina',
    'The Bravest Knight': 'USA',
    'Declared': 'USA',
    '12 Monkeys': 'USA',
    'El Negocio': 'Brazil',
    'They Come Knocking': 'USA',
    'The Bomber': 'USA',
    'Blinded by the Lights': 'UK',
    'Entre Nos': 'USA',
    'Good Bones': 'USA',
    'DriverX': 'USA',
    'Professional Fighters League': 'USA',
    'All That We Destroy': 'USA',
    'Ring Science': 'USA',
    'What’s Wrong With Secretary Kim': 'South Korea',
    'Fantastic Fights': 'USA',
    'Tyrel': 'USA',
    'The Prospects': 'USA',
    'Legendary Catch': 'USA',
    'Havana Street Party Presents Orishas': 'USA',
    'American Gods': 'USA',
    'Hang-Ups': 'UK',
    'Puppies vs. the World': 'USA',
    'Treehouse': 'USA',
    'Unikitty en Español': 'USA',
    'We Are LAFC': 'USA',
    'Unbanned: The Legend of AJ1': 'USA',
    'Down': 'USA',
    'The Pillars Of The Earth': 'UK',
    'World Without End (2012)': 'UK',
    'Butterfly (2018)': 'Australia',
    'Truth and Lies: Monica and Bill': 'USA',
    'UFC Destined': 'USA',
    'Dead by Dawn': 'USA',
    'Kaguya-sama: Love Is War': 'Japan',
    'Comrades & Cash: How Money Found Its Way Through the Iron Curtain': 'USA',
    'UFC 25 Greatest Fights': 'USA',
    'UFC Fight Flashback': 'USA',
    'UFC Main Event': 'USA',
    'UFC Reloaded': 'USA',
    'UFC Top 10': 'USA',
    'A Killer on Floor 32': 'USA',
    'Polly Pocket': 'USA',
    'Every Other Holiday': 'USA',
    'Pooka!': 'USA',
    'NBA Rooks': 'USA',
    'The Powerpuff Girls (2016)': 'USA',
    'Casi Leyendas': 'Spain',
    'Señor, Dame Paciencia': 'Mexico',
    'Damascus Cover': 'USA',
    'Dietland': 'USA',
    'SIX': 'USA',
    'The 12th Man': 'Norway',
    'Earn Everything': 'USA',
    'NBA: Year One': 'USA',
    'The Body': 'USA',
    'El Clon': 'Brazil',
    'Haunting, Horrifying Sounds from Beyond the Grave': 'USA',
    'The Box': 'USA',
    'A 2nd Chance': 'USA',
    'Truth and Lies: Jonestown, Paradise Lost': 'USA',
    'The Archer': 'USA',
    'Aurora (TV)': 'USA',
    'Training Days: Rolling with the Tide': 'USA',
    'Good Behavior': 'USA',
    'Warriors of Liberty City': 'USA',
    'Cupcake Wars': 'USA',
    'America To Me': 'USA',
    'Pasión Prohibida': 'USA',
    'Perro Amor': 'USA',
    "Tim & Eric's Bedtime Stories": 'USA',
    'Enhanced': 'USA',
    'Pocket.watch Ryan ToysReview Ultimate mishmash': 'USA',
    'Santa Diabla': 'USA',
    'Corazón valiente': 'USA',
    'Classic Wimbledon': 'UK',
    'Jorge el Curioso 3: De regreso a la Jungla': 'USA',
    'Nine for IX': 'USA',
    'When Shall We Kiss': 'USA',
    'Cheddar Features': 'USA',
    'Money Menu': 'USA',
    '(Dub) Sword Art Online: The Movie - Ordinal Scale': 'Japan',
    '(Sub) Sword Art Online: The Movie - Ordinal Scale': 'Japan',
    'Cheddar Explains': 'USA',
    'Last Train to Russia': 'Russia',
    "It's a Disaster": 'USA',
    'Dueños del Paraíso': 'USA',
    'El Señor de los Cielos': 'Mexico',
    'La Patrona': 'Mexico',
    'Señora Acero': 'Mexico',
    'Teen Titans Go! en Español': 'USA',
    'Mom and Dad': 'USA',
    'Detail': 'USA',
    'PERSONA5 the Animation': 'Japan',
    'Magic City': 'USA',
    'The Killer Speaks': 'USA',
    'March of the Penguins 2: The Next Step': 'France',
    '4 Lovers': 'France',
    'Deadliest Catch': 'USA',
    'Mobile Suit Gundam UC (Unicorn)': 'Japan',
    'SC Featured': 'USA',
    'Becoming': 'USA',
    'Fantasmagorias': 'Spain',
    '30 for 30 Shorts': 'USA',
    'Indy 500': 'USA',
    'Classic Boxing': 'USA',
    'O.J.: Made in America': 'USA',
    'The Masters Films': 'USA',
    '28 Hotel Rooms': 'USA',
    'The Girlfriend Experience': 'USA',
    'Wasteland': 'UK',
    "Gordon Ramsay's Ultimate Home Cooking": 'UK',
    'Doozers en Español': 'USA',
    'The House': 'USA',
    'Haunted Screens': 'USA',
    '(Dub) Dragon Age: Dawn of the Seeker': 'Japan',
    '(Dub) Mass Effect: Paragon Lost': 'Japan',
    'Looking': 'USA',
    'Bordertown': 'Finland',
    'Black-ish en Español': 'USA',
    'Mobile Suit Gundam The Origin': 'Japan',
    'Blue Bloods en Español': 'USA',
    'Elementary en Español': 'USA',
    'Rosaline': 'USA',
    'The Goldbergs en Español': 'USA',
    'Heroes Cotidianos': 'Colombia',
    'The Awesomes en Español': 'USA',
    'HAPPYish': 'USA',
    'The Borgias': 'USA',
    'The Green Room With Paul Provenza': 'USA',
    'The Bravest Knight Who Ever Lived': 'USA',
    'Hello Ladies': 'UK',
    'Garfunkel And Oates': 'USA',
    '(Sub) Legend of Heroes: Trails in the Sky': 'Japan'
}

# %% [markdown]
# # End

# %%
merged_dict = {key: val for dictionary in (a,b,c,d,e,f,g,h,i,j,k) for key, val in dictionary.items()}

# %%
len(merged_dict)
# Out:
# 1194

# %%
for i in list(df_cleaned[df_cleaned['country'].isnull()==True].index):
    try:
        df_cleaned['country'][i] = merged_dict[df_cleaned['title'][i]]
    except:
        print(i)
# Out:
# 726
# 3051
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1149937267.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['country'][i] = merged_dict[df_cleaned['title'][i]]
# ...

# %%
df_cleaned['country'][524] = 'USA'
# Out:
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1274460918.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['country'][524] = 'USA'
# ...

# %% [markdown]
# * Checking multi-continent (Maybe there are multiple countries but they might be from the same continent)

# %%
df_cleaned['continent'].unique()
# Out:
# array(['North America', nan, 'Africa', 'Europe', 'Oceania', 'Asia',
#        'Multi-Continent', 'South America'], dtype=object)

# %%
# df_cleaned['continent'].value_counts()
continents_mix = {}
for i in list(df_cleaned[df_cleaned['continent']=='Multi-Continent'].index):
    tmp_cont = []
    for country in df_cleaned.loc[i]['country_cleaned']:
        if country.strip():
            try:
                tmp_cont.append(country_to_continent(country_name=country.strip()))
            except:
                print(i, country)
    continents_mix[i] = tmp_cont

# %%
for k, v in continents_mix.items():
    if list(set(v)).__len__() == 1:
        df_cleaned['continent'][k] = list(set(v))[0]
    else:
        df_cleaned['continent'][k] = "Multi-Continent"
# Out:
# /var/folders/hs/n_n6ry4j37s9rkkh26n8m01r0000gn/T/ipykernel_61082/1207058120.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cleaned['continent'][k] = list(set(v))[0]
# ...

# %%
df_cleaned['continent'].value_counts()
# Out:
# continent
# North America      1637
# Asia                249
# Europe              212
# Multi-Continent     115
# Oceania              36
# South America        11
# Africa                4
# Name: count, dtype: int64

# %% [markdown]
# * Oceania is basically Australia, New Zealand and a few other pacific islands --> from internet (we can replace it to australia as well)

# %%
df_cleaned['type'].value_counts()
# Out:
# type
# TV Show    1193
# Movie      1177
# Name: count, dtype: int64

# %%
'''
ratings = {
    'Movie Ratings': {
        'G': 'General Audience - All ages.',
        'PG': 'Parental Guidance - Some material not suitable for children.',
        'PG-13': 'Parents Cautioned - Some material may not be suitable for under 13.',
        'R': 'Restricted - Under 17 requires an adult guardian.',
        'NC-17': 'Adults Only - No one 17 and under admitted.',
        'NR': 'Not Rated - Older movies before rating system.',
        'UR': 'Unrated - Often direct-to-video or re-releases with added content.'
    },
    'TV Ratings': {
        'TV-Y': 'All Children - For very young children (2-6 years old).',
        'TV-Y7': 'Older Children - Suitable for 7 and up.',
        'TV-Y7-FV': 'Older Children - May contain intense fantasy violence.',
        'TV-G': 'General Audience - Suitable for all ages.',
        'TV-PG': 'Parental Guidance - May contain moderate language or violence.',
        'TV-14': 'Parents Cautioned - May contain strong language or violence.',
        'TV-MA': 'Mature Audience - Unsuitable for children under 17.'
    }
}

'''

# %%
df_cleaned['duration'].value_counts(), df_cleaned['duration'].nunique()
# Out:
# (duration
#  1 Season      705
#  2 Seasons     220
#  3 Seasons      86
#  4 Seasons      67
#  5 Seasons      42
#               ...
#  142 min         1
#  63 min          1
#  65 min          1
#  70 min          1
#  22 Seasons      1
#  Name: count, Length: 111, dtype: int64,
#  111)

# %%
df_cleaned.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director           2367
# cast               2370
# country               1
# date_added            0
# release_year          0
# rating              490
# duration            428
# listed_in             0
# description           3
# country_cleaned       1
# continent           106
# month                 0
# day                   0
# year                  0
# difference            0
# dtype: int64

# %%
len(df_cleaned)
# Out:
# 2370

# %%
df_cleaned.dropna(subset=['continent', 'rating', 'duration'], inplace=True)

# %%
df_cleaned.reset_index(inplace=True, drop=True)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1485 entries, 0 to 1484
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   type             1485 non-null   object
#  1   date_added       1485 non-null   datetime64[ns]
#  2   month            1485 non-null   int32
#  3   day              1485 non-null   int32
#  4   year             1485 non-null   int32
#  5   release_year     1485 non-null   int64
#  6   rating           1485 non-null   object
#  7   duration_min     543 non-null    object
#  8   duration_season  1485 non-null   object
#  9   difference       1485 non-null   int64
#  10  continent        1485 non-null   object
#  11  country_cleaned  0 non-null      float64
#  12  country          1485 non-null   object
#  13  duration         1485 non-null   object
#  14  listed_in        1485 non-null   object
#  15  description      1485 non-null   object
# ...

# %%
season = 0
minu = 0
for i in range(len(df_cleaned)):
    if df_cleaned['duration'][i].lower().__contains__("season"):
        season+=1
    elif df_cleaned['duration'][i].lower().__contains__("min"):
        minu+=1

season, minu
# Out:
# (942, 543)

# %%
duration_min = []
duration_season = []
for i in range(len(df_cleaned)):
    if df_cleaned['duration'][i].lower().__contains__("season"):
        duration_season.append(df_cleaned['duration'][i].lower().strip("seasons").strip("season").strip())
    else:
        duration_season.append("NA")
    if df_cleaned['duration'][i].lower().__contains__("min"):
        duration_min.append(df_cleaned['duration'][i].lower().strip("min").strip())
    else:
        duration_min.append(np.nan)

# %%
len(duration_min), len(duration_season)
# Out:
# (1485, 1485)

# %%
df_cleaned['duration_min'] = duration_min
df_cleaned['duration_season'] = duration_season

# %%
df_cleaned['continent'].value_counts()
# Out:
# continent
# north america      1076
# asia                191
# europe              110
# multi-continent      86
# oceania              13
# south america         6
# africa                3
# Name: count, dtype: int64

# %%
df_cleaned.columns
# Out:
# Index(['type', 'date_added', 'month', 'day', 'year', 'release_year', 'rating',
#        'duration_min', 'duration_season', 'difference', 'continent',
#        'country_cleaned', 'country', 'duration', 'listed_in', 'description',
#        'show_id', 'director', 'cast', 'title'],
#       dtype='object')

# %%
df_cleaned = df_cleaned[['type', 'date_added', 'month', 'day', 'year', 'release_year', 'rating', 'duration_min', 'duration_season', 
                         'difference', 'continent', 'country_cleaned', 'country', 'duration', 'listed_in', 'description', 'show_id', 'director', 
                         'cast', 'title']]

# %%
df_cleaned.columns
# Out:
# Index(['type', 'date_added', 'month', 'day', 'year', 'release_year', 'rating',
#        'duration_min', 'duration_season', 'difference', 'continent',
#        'country_cleaned', 'country', 'duration', 'listed_in', 'description',
#        'show_id', 'director', 'cast', 'title'],
#       dtype='object')

# %%
df_cleaned.head(2)
# Out:
#     type date_added  month  day  year  release_year rating duration_min  \
# 0  movie 2021-10-23     10   23  2021          2021  pg-13          108
# 1  movie 2021-10-22     10   22  2021          2021      r           97
#
#   duration_season  difference      continent  country_cleaned       country  \
# 0              NA           9  north america              NaN           usa
# 1              NA           9         africa              NaN  south africa
#
#   duration         listed_in  \
# 0  108 min  action, thriller
# 1   97 min            horror
#
#                                          description show_id director  cast  \
# 0  a hardened arizona rancher tries to protect an...      s3      NaN   NaN
# 1  a forest ranger and two survivalists with a cu...      s4      NaN   NaN
#
#           title
# 0  the marksman
# 1          gaia

# %%
def df_normalize_strings(df, col):
    df[col] = df[col].str.lower() # change everything to lower cases
    df[col] = df[col].fillna('missing') # make None -> missing
    df[col] = df[col].replace(np.nan, 'missing')
    df[col] = df[col].replace('none or unspecified', 'missing')
    df[col] = df[col].replace('none', 'missing')
    df[col] = df[col].replace('no', 'missing')
    df[col] = df[col].replace('#name?', 'missing')
    df[col] = df[col].replace('', 'missing') # empty -> missing
def normalize_all_columns(df):
    for col in df.columns:
        if df[col].dtype == 'object':  # Only apply to string columns
            df_normalize_strings(df, col)

# %%
normalize_all_columns(df_cleaned)

# %%
df_cleaned.dtypes
# Out:
# type                       object
# date_added         datetime64[ns]
# month                       int32
# day                         int32
# year                        int32
# release_year                int64
# rating                     object
# duration_min               object
# duration_season            object
# difference                  int64
# continent                  object
# country_cleaned           float64
# country                    object
# duration                   object
# listed_in                  object
# description                object
# show_id                    object
# director                   object
# cast                      float64
# title                      object
# dtype: object

# %%
# df_cleaned['continent'].replace('missing', np.nan, inplace=True)
# df_cleaned.dropna(subset=['continent'], inplace=True)

# %%
# df_cleaned.replace('missing', np.nan, inplace=True)

# %%
df_cleaned.to_csv("Hulu_cleaned_1.csv", index=False)
# df_cleaned.to_csv("Hulu_for_difference.csv", index=False)

# %%
'''
WE CAN CHANGE THE ORDER OF THE QUESTIONS LATER ON TO FORM A MEANINGFUL FLOW

#1 (gopi)
Question: trend of how long does netflix take to add on the show of past vs current
Columns req: "difference", "type"
Comments: We can include the type as well (like how lon TV shows take to be added to Netflix in comparison to Movies)
Business perspective can be: If the time to be added to Netflix from the release date is lesser, it's a good point to attract the customers

#2 (ricky)
Question: are there any notictable patterns in type/content released over the past years. Which type has gotten more popular and released more
Columns req: "date_added"/"year", "type", "duration", "listed_in"
comments: we can plot something like, year/date will be on one axis and the other axis will have type | duration | listed_in (maybe a 1x3 subplots)
          we can also different plots for tv shows and movies since their duration values are different.
Business perspective: if there are more tv shows than movies, it indicates that netflix is trying increase the watch hours of the users since,
                         tv shows have more watch hours compared to movies (need to figure out, can't think of any good idea here).

#3 (victor)
Question: what age group are they targeting distrution of rating
Columns req: "rating", count of "type", "year" (maybe to show the trend in target audience)
comments: 
Business perspective: more content in the rating of "anyone can watch sort of type" means that the range and count of target audience
                     is more thus increasing the subscriptions (??? not quite sure here as well)

#4 (gopi)
Question: Global visualization
Columns req: "continent", ("country"),
business perspective: netflix catering to global audience

#5
Question: key directors and cast in the netflix ecosystem.
comments: Network graph of top directors/csat and their genres. (optional-not sure if this would work out, keeping it for now)

#6 (victor)
Question: use quarterly data to get counts of type released and see what types of shows are popular during which season
comments: Since most people have holidays in Dec/Jan, is the content more likely around tht season?
'''

# %%
df_cleaned.isnull().sum()
# Out:
# type                 0
# date_added           0
# month                0
# day                  0
# year                 0
# release_year         0
# rating               0
# duration_min         0
# duration_season      0
# difference           0
# continent            0
# country_cleaned      0
# country              0
# duration             0
# listed_in            0
# description          0
# show_id              0
# director             0
# cast               894
# title                0
# dtype: int64
